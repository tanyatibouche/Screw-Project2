# %% [markdown]
# <a href="https://colab.research.google.com/github/Emma-Coco/Screw-project/blob/main/Modele_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip screw_dataset.zip
# Out:
# Archive:  screw_dataset.zip
#    creating: screw_dataset/
#   inflating: __MACOSX/._screw_dataset
#   inflating: screw_dataset/.DS_Store
#   inflating: __MACOSX/screw_dataset/._.DS_Store
#    creating: screw_dataset/bad/
#   inflating: __MACOSX/screw_dataset/._bad
#    creating: screw_dataset/good/
#   inflating: __MACOSX/screw_dataset/._good
#   inflating: screw_dataset/bad/023_png.rf.53e5fc79e243548f8792354dae3acf09.jpg
#   inflating: __MACOSX/screw_dataset/bad/._023_png.rf.53e5fc79e243548f8792354dae3acf09.jpg
#   inflating: screw_dataset/bad/006_png.rf.dba2300aaf35998d723c334bd8d334f7.jpg
#   inflating: __MACOSX/screw_dataset/bad/._006_png.rf.dba2300aaf35998d723c334bd8d334f7.jpg
#   inflating: screw_dataset/bad/013_png.rf.54ba3ab35a37b312543c98d486034db1.jpg
#   inflating: __MACOSX/screw_dataset/bad/._013_png.rf.54ba3ab35a37b312543c98d486034db1.jpg
#   inflating: screw_dataset/bad/001_png.rf.a9c493c563488514026a6f9dee8e857c.jpg
#   inflating: __MACOSX/screw_dataset/bad/._001_png.rf.a9c493c563488514026a6f9dee8e857c.jpg
#   inflating: screw_dataset/bad/011_png.rf.d294060c2b2be8d6fb6b845cd0e34693.jpg
#   inflating: __MACOSX/screw_dataset/bad/._011_png.rf.d294060c2b2be8d6fb6b845cd0e34693.jpg
#   inflating: screw_dataset/bad/012_png.rf.9d12797e8abb02ee03fa10e7895ceb1d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.9d12797e8abb02ee03fa10e7895ceb1d.jpg
#   inflating: screw_dataset/bad/020_png.rf.dc2a0e26215cd1b737140ffa58c1c679.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.dc2a0e26215cd1b737140ffa58c1c679.jpg
#   inflating: screw_dataset/bad/007_png.rf.69dc5e94dbf8714c26724bbb5be63347.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.69dc5e94dbf8714c26724bbb5be63347.jpg
#   inflating: screw_dataset/bad/022_png.rf.028dbb8bd2a1e9811df7d512da0c2674.jpg
#   inflating: __MACOSX/screw_dataset/bad/._022_png.rf.028dbb8bd2a1e9811df7d512da0c2674.jpg
#   inflating: screw_dataset/bad/018_png.rf.06303412975ce19c2876ce965bfb707f.jpg
#   inflating: __MACOSX/screw_dataset/bad/._018_png.rf.06303412975ce19c2876ce965bfb707f.jpg
#   inflating: screw_dataset/bad/012_png.rf.300cc266031127237eb437902de4d063.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.300cc266031127237eb437902de4d063.jpg
#   inflating: screw_dataset/bad/010_png.rf.bbcb83034d5ba177ee6483ec2b0a2aba.jpg
#   inflating: __MACOSX/screw_dataset/bad/._010_png.rf.bbcb83034d5ba177ee6483ec2b0a2aba.jpg
#   inflating: screw_dataset/bad/000_png.rf.e52168c76dd0622609567018ec2d2fa6.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.e52168c76dd0622609567018ec2d2fa6.jpg
#   inflating: screw_dataset/bad/005_png.rf.d0158a43592f7b4b40160e4d3b1c7b13.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.d0158a43592f7b4b40160e4d3b1c7b13.jpg
#   inflating: screw_dataset/bad/001_png.rf.3e3776c79b85b931a720b42e7348d0ee.jpg
#   inflating: __MACOSX/screw_dataset/bad/._001_png.rf.3e3776c79b85b931a720b42e7348d0ee.jpg
#   inflating: screw_dataset/bad/008_png.rf.d86aab5bf31633a6b1ea3e1caf6fb89f.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.d86aab5bf31633a6b1ea3e1caf6fb89f.jpg
#   inflating: screw_dataset/bad/014_png.rf.8412a2a7addd6b41a428c0908aa0440d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.8412a2a7addd6b41a428c0908aa0440d.jpg
#   inflating: screw_dataset/bad/014_png.rf.ba298f72d2fee88ab17eaafd050053cf.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.ba298f72d2fee88ab17eaafd050053cf.jpg
#   inflating: screw_dataset/bad/017_png.rf.f6aaf044cc02e66f7c05e4115bf41680.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.f6aaf044cc02e66f7c05e4115bf41680.jpg
#   inflating: screw_dataset/bad/011_png.rf.612b1df8a5cb603feaa7ed830e61e0e7.jpg
#   inflating: __MACOSX/screw_dataset/bad/._011_png.rf.612b1df8a5cb603feaa7ed830e61e0e7.jpg
#   inflating: screw_dataset/bad/007_png.rf.97ae06828195065ac8cdff927b32a5e9.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.97ae06828195065ac8cdff927b32a5e9.jpg
#   inflating: screw_dataset/bad/015_png.rf.1043093eea84f9eb0a96183be21ab18a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._015_png.rf.1043093eea84f9eb0a96183be21ab18a.jpg
#   inflating: screw_dataset/bad/012_png.rf.601d1a8cbf16cb2a77c4b8eead13272c.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.601d1a8cbf16cb2a77c4b8eead13272c.jpg
#   inflating: screw_dataset/bad/014_png.rf.2e702e22c6ffd4a054c1a986e50a925c.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.2e702e22c6ffd4a054c1a986e50a925c.jpg
#   inflating: screw_dataset/bad/022_png.rf.247caf024b505e748df071cdf4d0d792.jpg
#   inflating: __MACOSX/screw_dataset/bad/._022_png.rf.247caf024b505e748df071cdf4d0d792.jpg
#   inflating: screw_dataset/bad/005_png.rf.241341f108b44e8c6257722fb0c8f956.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.241341f108b44e8c6257722fb0c8f956.jpg
#   inflating: screw_dataset/bad/000_png.rf.6c474f373cfee74f36bbece52d600ef2.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.6c474f373cfee74f36bbece52d600ef2.jpg
#   inflating: screw_dataset/bad/022_png.rf.4eadc8c393b50617b5fe0b74e566efa2.jpg
#   inflating: __MACOSX/screw_dataset/bad/._022_png.rf.4eadc8c393b50617b5fe0b74e566efa2.jpg
#   inflating: screw_dataset/bad/001_png.rf.0a5fad175175b02261690e3a3b7e794f.jpg
#   inflating: __MACOSX/screw_dataset/bad/._001_png.rf.0a5fad175175b02261690e3a3b7e794f.jpg
#   inflating: screw_dataset/bad/000_png.rf.e3146d38333f8a4872587d78ca4b7d77.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.e3146d38333f8a4872587d78ca4b7d77.jpg
#   inflating: screw_dataset/bad/020_png.rf.a1f958990a3a5f73a9836d553ee1b639.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.a1f958990a3a5f73a9836d553ee1b639.jpg
#   inflating: screw_dataset/bad/014_png.rf.617652ef66dba2dcc82ccbf4f6c82ab8.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.617652ef66dba2dcc82ccbf4f6c82ab8.jpg
#   inflating: screw_dataset/bad/011_png.rf.46825f4061cecd1972ff390e014e97fa.jpg
#   inflating: __MACOSX/screw_dataset/bad/._011_png.rf.46825f4061cecd1972ff390e014e97fa.jpg
#   inflating: screw_dataset/bad/009_png.rf.ae722e2958e43d43700acd94cec8aa38.jpg
#   inflating: __MACOSX/screw_dataset/bad/._009_png.rf.ae722e2958e43d43700acd94cec8aa38.jpg
#   inflating: screw_dataset/bad/013_png.rf.3bd49f22d8ccfe86d4f404a295895ed1.jpg
#   inflating: __MACOSX/screw_dataset/bad/._013_png.rf.3bd49f22d8ccfe86d4f404a295895ed1.jpg
#   inflating: screw_dataset/bad/000_png.rf.8c18aacbe9fd00e37ac37dcf2d75ea68.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.8c18aacbe9fd00e37ac37dcf2d75ea68.jpg
#   inflating: screw_dataset/bad/014_png.rf.48f8dc3ea1f4cc6dbaba33f20a13780e.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.48f8dc3ea1f4cc6dbaba33f20a13780e.jpg
#   inflating: screw_dataset/bad/009_png.rf.f3a327ae7d91da85664c04621bd38108.jpg
#   inflating: __MACOSX/screw_dataset/bad/._009_png.rf.f3a327ae7d91da85664c04621bd38108.jpg
#   inflating: screw_dataset/bad/007_png.rf.c411339e14a573331af4b0c491ba98c3.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.c411339e14a573331af4b0c491ba98c3.jpg
#   inflating: screw_dataset/bad/017_png.rf.f5a1823dff573238e03dbf99134ae60f.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.f5a1823dff573238e03dbf99134ae60f.jpg
#   inflating: screw_dataset/bad/005_png.rf.b2824341ebe08892a87109e848793b6a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.b2824341ebe08892a87109e848793b6a.jpg
#   inflating: screw_dataset/bad/017_png.rf.d5ff23fd6be6396950624b3af1232958.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.d5ff23fd6be6396950624b3af1232958.jpg
#   inflating: screw_dataset/bad/015_png.rf.cc343910c066a295156b93408c632b7a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._015_png.rf.cc343910c066a295156b93408c632b7a.jpg
#   inflating: screw_dataset/bad/002_png.rf.8b2d6c2ddc3e680b4c5b598d1ddb3577.jpg
#   inflating: __MACOSX/screw_dataset/bad/._002_png.rf.8b2d6c2ddc3e680b4c5b598d1ddb3577.jpg
#   inflating: screw_dataset/bad/008_png.rf.ddb9c3608f43af618b39b067123760fa.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.ddb9c3608f43af618b39b067123760fa.jpg
#   inflating: screw_dataset/bad/000_png.rf.e87e8a38022db5d701fed2aabfe3d2f8.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.e87e8a38022db5d701fed2aabfe3d2f8.jpg
#   inflating: screw_dataset/bad/004_png.rf.6874d488bd17f75b0c4f1afdbdae2816.jpg
#   inflating: __MACOSX/screw_dataset/bad/._004_png.rf.6874d488bd17f75b0c4f1afdbdae2816.jpg
#   inflating: screw_dataset/bad/008_png.rf.3f56172f77e514205dc11f6df5e385d8.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.3f56172f77e514205dc11f6df5e385d8.jpg
#   inflating: screw_dataset/bad/021_png.rf.3a3742988025dc8b7198d1df51dc2e73.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.3a3742988025dc8b7198d1df51dc2e73.jpg
#   inflating: screw_dataset/bad/012_png.rf.fe96f1dac4046d5eebce5344919c45fa.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.fe96f1dac4046d5eebce5344919c45fa.jpg
#   inflating: screw_dataset/bad/000_png.rf.969137da7c830490101ff17a9a9b6347.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.969137da7c830490101ff17a9a9b6347.jpg
#   inflating: screw_dataset/bad/008_png.rf.1ad3b6a65973e50c8fd2797defc2d54a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.1ad3b6a65973e50c8fd2797defc2d54a.jpg
#   inflating: screw_dataset/bad/012_png.rf.ddfa2e4855d0fd90791705f62d19c321.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.ddfa2e4855d0fd90791705f62d19c321.jpg
#   inflating: screw_dataset/bad/021_png.rf.688a8579b79c3fcb7210282da651e724.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.688a8579b79c3fcb7210282da651e724.jpg
#   inflating: screw_dataset/bad/023_png.rf.6b8e8a2d556551584fa6421c222dcb25.jpg
#   inflating: __MACOSX/screw_dataset/bad/._023_png.rf.6b8e8a2d556551584fa6421c222dcb25.jpg
#   inflating: screw_dataset/bad/006_png.rf.1f50fc13cda4c89d5ce6e44046abcaf4.jpg
#   inflating: __MACOSX/screw_dataset/bad/._006_png.rf.1f50fc13cda4c89d5ce6e44046abcaf4.jpg
#   inflating: screw_dataset/bad/008_png.rf.cc781c112070ce698bd6e18c2d700c0e.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.cc781c112070ce698bd6e18c2d700c0e.jpg
#   inflating: screw_dataset/bad/019_png.rf.cf37ee67b5db992fe4502609c3d7e327.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.cf37ee67b5db992fe4502609c3d7e327.jpg
#   inflating: screw_dataset/bad/022_png.rf.97456f0edff8636541677f3981993c7b.jpg
#   inflating: __MACOSX/screw_dataset/bad/._022_png.rf.97456f0edff8636541677f3981993c7b.jpg
#   inflating: screw_dataset/bad/022_png.rf.e88cef4f761a3612c250f445fe857b50.jpg
#   inflating: __MACOSX/screw_dataset/bad/._022_png.rf.e88cef4f761a3612c250f445fe857b50.jpg
#   inflating: screw_dataset/bad/009_png.rf.cc8c4b239827554a1f9b2f149c222fd4.jpg
#   inflating: __MACOSX/screw_dataset/bad/._009_png.rf.cc8c4b239827554a1f9b2f149c222fd4.jpg
#   inflating: screw_dataset/bad/020_png.rf.19425cde859360bc8cf9988b845c6c1d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.19425cde859360bc8cf9988b845c6c1d.jpg
#   inflating: screw_dataset/bad/020_png.rf.ec62ddfb41057052b36241d2dd30b1d9.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.ec62ddfb41057052b36241d2dd30b1d9.jpg
#   inflating: screw_dataset/bad/012_png.rf.8111337002565a5bd3dda2b3b8bb8f49.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.8111337002565a5bd3dda2b3b8bb8f49.jpg
#   inflating: screw_dataset/bad/001_png.rf.eb5a642ddde27397b7ef3abb58a43ff5.jpg
#   inflating: __MACOSX/screw_dataset/bad/._001_png.rf.eb5a642ddde27397b7ef3abb58a43ff5.jpg
#   inflating: screw_dataset/bad/004_png.rf.8e801f1afd395cd207ed1b2cd387d64a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._004_png.rf.8e801f1afd395cd207ed1b2cd387d64a.jpg
#   inflating: screw_dataset/bad/009_png.rf.5d1e437e8c60fa83d279d984abe61656.jpg
#   inflating: __MACOSX/screw_dataset/bad/._009_png.rf.5d1e437e8c60fa83d279d984abe61656.jpg
#   inflating: screw_dataset/bad/018_png.rf.adbd3216a18eee57a240ec5d104d74e9.jpg
#   inflating: __MACOSX/screw_dataset/bad/._018_png.rf.adbd3216a18eee57a240ec5d104d74e9.jpg
#   inflating: screw_dataset/bad/003_png.rf.b5ff2c8ce5caaaf97fcf792c2050df74.jpg
#   inflating: __MACOSX/screw_dataset/bad/._003_png.rf.b5ff2c8ce5caaaf97fcf792c2050df74.jpg
#   inflating: screw_dataset/bad/019_png.rf.d58d0b648d0b412d075efd5ec5654d2d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.d58d0b648d0b412d075efd5ec5654d2d.jpg
#   inflating: screw_dataset/bad/013_png.rf.ba4efeb77fbc2b4f0ee5bae969b5112d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._013_png.rf.ba4efeb77fbc2b4f0ee5bae969b5112d.jpg
#   inflating: screw_dataset/bad/006_png.rf.5d709eba7053fb67354530899bc4a6dd.jpg
#   inflating: __MACOSX/screw_dataset/bad/._006_png.rf.5d709eba7053fb67354530899bc4a6dd.jpg
#   inflating: screw_dataset/bad/016_png.rf.b2242578f5c919bbd257ca36ee9cdfc1.jpg
#   inflating: __MACOSX/screw_dataset/bad/._016_png.rf.b2242578f5c919bbd257ca36ee9cdfc1.jpg
#   inflating: screw_dataset/bad/007_png.rf.12d603dbf4b39f034023e4b1ec300868.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.12d603dbf4b39f034023e4b1ec300868.jpg
#   inflating: screw_dataset/bad/014_png.rf.b2884497a2dec966afb7c260ae8895a2.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.b2884497a2dec966afb7c260ae8895a2.jpg
#   inflating: screw_dataset/bad/002_png.rf.c7a8f01ef3142352062c343e8ae45a92.jpg
#   inflating: __MACOSX/screw_dataset/bad/._002_png.rf.c7a8f01ef3142352062c343e8ae45a92.jpg
#   inflating: screw_dataset/bad/022_png.rf.dd0e84b38add3da3ce2ac07fef6a9ca0.jpg
#   inflating: __MACOSX/screw_dataset/bad/._022_png.rf.dd0e84b38add3da3ce2ac07fef6a9ca0.jpg
#   inflating: screw_dataset/bad/016_png.rf.ef023dcfe35c2abc03cee16b486857d4.jpg
#   inflating: __MACOSX/screw_dataset/bad/._016_png.rf.ef023dcfe35c2abc03cee16b486857d4.jpg
#   inflating: screw_dataset/bad/006_png.rf.c75e651c0cbb69d5516d187edde13b67.jpg
#   inflating: __MACOSX/screw_dataset/bad/._006_png.rf.c75e651c0cbb69d5516d187edde13b67.jpg
#   inflating: screw_dataset/bad/011_png.rf.138ef185f57cf2c9031198d242e08eb5.jpg
#   inflating: __MACOSX/screw_dataset/bad/._011_png.rf.138ef185f57cf2c9031198d242e08eb5.jpg
#   inflating: screw_dataset/bad/020_png.rf.2bda601cc05523dfa22445f17f6d49e4.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.2bda601cc05523dfa22445f17f6d49e4.jpg
#   inflating: screw_dataset/bad/015_png.rf.1f2eb322bc949c0512c61497e2e3c3e1.jpg
#   inflating: __MACOSX/screw_dataset/bad/._015_png.rf.1f2eb322bc949c0512c61497e2e3c3e1.jpg
#   inflating: screw_dataset/bad/022_png.rf.cdfb7d40002ae23bc11835dc43220224.jpg
#   inflating: __MACOSX/screw_dataset/bad/._022_png.rf.cdfb7d40002ae23bc11835dc43220224.jpg
#   inflating: screw_dataset/bad/008_png.rf.18453ca061944ecd367fc766f62d676b.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.18453ca061944ecd367fc766f62d676b.jpg
#   inflating: screw_dataset/bad/008_png.rf.ab90324185300cf96bd5e5a6f9df67fc.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.ab90324185300cf96bd5e5a6f9df67fc.jpg
#   inflating: screw_dataset/bad/008_png.rf.faf6fa1d59f9153c58d272db60803dfc.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.faf6fa1d59f9153c58d272db60803dfc.jpg
#   inflating: screw_dataset/bad/004_png.rf.d34d40cd2a114fd074fef4c22f30c30c.jpg
#   inflating: __MACOSX/screw_dataset/bad/._004_png.rf.d34d40cd2a114fd074fef4c22f30c30c.jpg
#   inflating: screw_dataset/bad/021_png.rf.baebca34615d1dcc49031c8348f42268.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.baebca34615d1dcc49031c8348f42268.jpg
#   inflating: screw_dataset/bad/016_png.rf.728d997d56b2e9fc8778ad43be106855.jpg
#   inflating: __MACOSX/screw_dataset/bad/._016_png.rf.728d997d56b2e9fc8778ad43be106855.jpg
#   inflating: screw_dataset/bad/004_png.rf.8fcc218c7c36a2788d71bfb24f97856a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._004_png.rf.8fcc218c7c36a2788d71bfb24f97856a.jpg
#   inflating: screw_dataset/bad/009_png.rf.2231b73198f7bd898e179d75be112984.jpg
#   inflating: __MACOSX/screw_dataset/bad/._009_png.rf.2231b73198f7bd898e179d75be112984.jpg
#   inflating: screw_dataset/bad/018_png.rf.f4e85114ec7ab430cb4a3dc180168165.jpg
#   inflating: __MACOSX/screw_dataset/bad/._018_png.rf.f4e85114ec7ab430cb4a3dc180168165.jpg
#   inflating: screw_dataset/bad/000_png.rf.1578c55ecab605301b94780b6bb22f2a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.1578c55ecab605301b94780b6bb22f2a.jpg
#   inflating: screw_dataset/bad/017_png.rf.826a7f541c37536e9f66812099e611f5.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.826a7f541c37536e9f66812099e611f5.jpg
#   inflating: screw_dataset/bad/019_png.rf.9348c01d8f776d01a75cc65be40b10c3.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.9348c01d8f776d01a75cc65be40b10c3.jpg
#   inflating: screw_dataset/bad/003_png.rf.b12596dbf09fe1939a4fcbdd1f8fef5d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._003_png.rf.b12596dbf09fe1939a4fcbdd1f8fef5d.jpg
#   inflating: screw_dataset/bad/019_png.rf.58ff7fe0edd13347f44df5040fdae607.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.58ff7fe0edd13347f44df5040fdae607.jpg
#   inflating: screw_dataset/bad/021_png.rf.5040139dccdbd7d15a773de6b48cbea2.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.5040139dccdbd7d15a773de6b48cbea2.jpg
#   inflating: screw_dataset/bad/015_png.rf.3114b304447fe6c216e3e9647600bc05.jpg
#   inflating: __MACOSX/screw_dataset/bad/._015_png.rf.3114b304447fe6c216e3e9647600bc05.jpg
#   inflating: screw_dataset/bad/019_png.rf.43be03a288441c18db1142ea19603aca.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.43be03a288441c18db1142ea19603aca.jpg
#   inflating: screw_dataset/bad/003_png.rf.ef4205dc03023735101b94ed7d0bde71.jpg
#   inflating: __MACOSX/screw_dataset/bad/._003_png.rf.ef4205dc03023735101b94ed7d0bde71.jpg
#   inflating: screw_dataset/bad/017_png.rf.289890761c45b80513be4a8816c0d99d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.289890761c45b80513be4a8816c0d99d.jpg
#   inflating: screw_dataset/bad/017_png.rf.fe4b906bb2aa2460535f7c609cc516cf.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.fe4b906bb2aa2460535f7c609cc516cf.jpg
#   inflating: screw_dataset/bad/012_png.rf.bfe21819fe00efc62a1f0cc5db345df3.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.bfe21819fe00efc62a1f0cc5db345df3.jpg
#   inflating: screw_dataset/bad/020_png.rf.0e9cb0793f2a9830867f46b1ce2ea565.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.0e9cb0793f2a9830867f46b1ce2ea565.jpg
#   inflating: screw_dataset/bad/014_png.rf.8e2b9d30f14ef746118341f0bdeab016.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.8e2b9d30f14ef746118341f0bdeab016.jpg
#   inflating: screw_dataset/bad/012_png.rf.664932f8bc4ef244fab3a2351a309851.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.664932f8bc4ef244fab3a2351a309851.jpg
#   inflating: screw_dataset/bad/019_png.rf.4b35efb9b9152cd7e14c08cac9413e33.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.4b35efb9b9152cd7e14c08cac9413e33.jpg
#   inflating: screw_dataset/bad/003_png.rf.c044a3d62d31338f14f1877d87781406.jpg
#   inflating: __MACOSX/screw_dataset/bad/._003_png.rf.c044a3d62d31338f14f1877d87781406.jpg
#   inflating: screw_dataset/bad/006_png.rf.319e0dbead6412fc0b9f8b7c2c44066b.jpg
#   inflating: __MACOSX/screw_dataset/bad/._006_png.rf.319e0dbead6412fc0b9f8b7c2c44066b.jpg
#   inflating: screw_dataset/bad/021_png.rf.521b4cb670b317bf1e1d021164973da2.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.521b4cb670b317bf1e1d021164973da2.jpg
#   inflating: screw_dataset/bad/005_png.rf.7cf6fde547e384e908d79c2be5946245.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.7cf6fde547e384e908d79c2be5946245.jpg
#   inflating: screw_dataset/bad/007_png.rf.4d0041b584386e6b1588a3f5139be85e.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.4d0041b584386e6b1588a3f5139be85e.jpg
#   inflating: screw_dataset/bad/008_png.rf.ed3266e5047f2945d0f7be720262fec0.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.ed3266e5047f2945d0f7be720262fec0.jpg
#   inflating: screw_dataset/bad/003_png.rf.bdc9ccf0d45d2c79a10235e7311df0c5.jpg
#   inflating: __MACOSX/screw_dataset/bad/._003_png.rf.bdc9ccf0d45d2c79a10235e7311df0c5.jpg
#   inflating: screw_dataset/bad/005_png.rf.5937a54a4ecd80c6497195f8dd27203d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.5937a54a4ecd80c6497195f8dd27203d.jpg
#   inflating: screw_dataset/bad/022_png.rf.4004e188d178fd01225d8d222827dabb.jpg
#   inflating: __MACOSX/screw_dataset/bad/._022_png.rf.4004e188d178fd01225d8d222827dabb.jpg
#   inflating: screw_dataset/bad/014_png.rf.a21f5a58ced702dc565f8f95bc499ef3.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.a21f5a58ced702dc565f8f95bc499ef3.jpg
#   inflating: screw_dataset/bad/018_png.rf.1d8854f5f594244012cdfd392a02d192.jpg
#   inflating: __MACOSX/screw_dataset/bad/._018_png.rf.1d8854f5f594244012cdfd392a02d192.jpg
#   inflating: screw_dataset/bad/021_png.rf.bc23ac48c84c4f621e186d311b66c2f7.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.bc23ac48c84c4f621e186d311b66c2f7.jpg
#   inflating: screw_dataset/bad/019_png.rf.293c7f2cc23cfd6e227db7841c3db96b.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.293c7f2cc23cfd6e227db7841c3db96b.jpg
#   inflating: screw_dataset/bad/014_png.rf.4ca1cfeac8bf261631c6c97dcf1a46e9.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.4ca1cfeac8bf261631c6c97dcf1a46e9.jpg
#   inflating: screw_dataset/bad/010_png.rf.2a7706a5940def4635e1bd599c91a715.jpg
#   inflating: __MACOSX/screw_dataset/bad/._010_png.rf.2a7706a5940def4635e1bd599c91a715.jpg
#   inflating: screw_dataset/bad/023_png.rf.dbd2bb3a950aefec1bfe141aa1d7246a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._023_png.rf.dbd2bb3a950aefec1bfe141aa1d7246a.jpg
#   inflating: screw_dataset/bad/015_png.rf.ac04d3fecbe5744b15b2765c419df7a8.jpg
#   inflating: __MACOSX/screw_dataset/bad/._015_png.rf.ac04d3fecbe5744b15b2765c419df7a8.jpg
#   inflating: screw_dataset/bad/019_png.rf.8994cd0e0cfe96c7f3a908e1d28568c2.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.8994cd0e0cfe96c7f3a908e1d28568c2.jpg
#   inflating: screw_dataset/bad/012_png.rf.372c51719054df25d7b31fc4230660bb.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.372c51719054df25d7b31fc4230660bb.jpg
#   inflating: screw_dataset/bad/014_png.rf.ec623be0ccf0146687edf6fc7d743631.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.ec623be0ccf0146687edf6fc7d743631.jpg
#   inflating: screw_dataset/bad/015_png.rf.fe50a480d2c25c10e5371605e86b929b.jpg
#   inflating: __MACOSX/screw_dataset/bad/._015_png.rf.fe50a480d2c25c10e5371605e86b929b.jpg
#   inflating: screw_dataset/bad/011_png.rf.24186cd9c16b93e88ccb88cd5da1563d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._011_png.rf.24186cd9c16b93e88ccb88cd5da1563d.jpg
#   inflating: screw_dataset/bad/008_png.rf.0ccab0d165e65b3d9fc165cc3ae98e6e.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.0ccab0d165e65b3d9fc165cc3ae98e6e.jpg
#   inflating: screw_dataset/bad/013_png.rf.b68b7bceacc3af8a6c3fd52c122270aa.jpg
#   inflating: __MACOSX/screw_dataset/bad/._013_png.rf.b68b7bceacc3af8a6c3fd52c122270aa.jpg
#   inflating: screw_dataset/bad/006_png.rf.2d5eeeded4779cef199bbab176b18fbb.jpg
#   inflating: __MACOSX/screw_dataset/bad/._006_png.rf.2d5eeeded4779cef199bbab176b18fbb.jpg
#   inflating: screw_dataset/bad/010_png.rf.0c6cba0657a20d1e8a91a877fe3f8e80.jpg
#   inflating: __MACOSX/screw_dataset/bad/._010_png.rf.0c6cba0657a20d1e8a91a877fe3f8e80.jpg
#   inflating: screw_dataset/bad/011_png.rf.9e9f4543d99fbf86bb68b44349adbfa5.jpg
#   inflating: __MACOSX/screw_dataset/bad/._011_png.rf.9e9f4543d99fbf86bb68b44349adbfa5.jpg
#   inflating: screw_dataset/bad/005_png.rf.b15cf21c7429b5037e7e4cb0b606d597.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.b15cf21c7429b5037e7e4cb0b606d597.jpg
#   inflating: screw_dataset/bad/013_png.rf.aa4b4734a0a5d38f89e00d75810912c8.jpg
#   inflating: __MACOSX/screw_dataset/bad/._013_png.rf.aa4b4734a0a5d38f89e00d75810912c8.jpg
#   inflating: screw_dataset/bad/013_png.rf.0d0ca88ec7eaf8fa88f95243d4b7d7d6.jpg
#   inflating: __MACOSX/screw_dataset/bad/._013_png.rf.0d0ca88ec7eaf8fa88f95243d4b7d7d6.jpg
#   inflating: screw_dataset/bad/017_png.rf.7c706822162526559a968d9d89a92d07.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.7c706822162526559a968d9d89a92d07.jpg
#   inflating: screw_dataset/bad/019_png.rf.1805a7fa500db60295ede89cb0a5de31.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.1805a7fa500db60295ede89cb0a5de31.jpg
#   inflating: screw_dataset/bad/008_png.rf.58794030cc180ee09e3c6284a5d0ace7.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.58794030cc180ee09e3c6284a5d0ace7.jpg
#   inflating: screw_dataset/bad/012_png.rf.7c3cd488790823ad9d1ac4c456100c5e.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.7c3cd488790823ad9d1ac4c456100c5e.jpg
#   inflating: screw_dataset/bad/019_png.rf.c84dbd7af9813a8767a663a8f8c49f63.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.c84dbd7af9813a8767a663a8f8c49f63.jpg
#   inflating: screw_dataset/bad/002_png.rf.6c2023c585df3bf80a1ca4aa9cc98354.jpg
#   inflating: __MACOSX/screw_dataset/bad/._002_png.rf.6c2023c585df3bf80a1ca4aa9cc98354.jpg
#   inflating: screw_dataset/bad/021_png.rf.ac511deaf1e534027657a04db07f75b1.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.ac511deaf1e534027657a04db07f75b1.jpg
#   inflating: screw_dataset/bad/018_png.rf.484a329e0ffd1fd7e9847dae62d5b513.jpg
#   inflating: __MACOSX/screw_dataset/bad/._018_png.rf.484a329e0ffd1fd7e9847dae62d5b513.jpg
#   inflating: screw_dataset/bad/022_png.rf.f7efa4df9ed23b80e135621b1b1106cc.jpg
#   inflating: __MACOSX/screw_dataset/bad/._022_png.rf.f7efa4df9ed23b80e135621b1b1106cc.jpg
#   inflating: screw_dataset/bad/007_png.rf.feff1ecdf03b9e8edcfaef31127ca25f.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.feff1ecdf03b9e8edcfaef31127ca25f.jpg
#   inflating: screw_dataset/bad/020_png.rf.b27de2ee4d5316b24c5bfd607c073c27.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.b27de2ee4d5316b24c5bfd607c073c27.jpg
#   inflating: screw_dataset/bad/014_png.rf.65fa1b423910822c16a2766ec896471a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.65fa1b423910822c16a2766ec896471a.jpg
#   inflating: screw_dataset/bad/007_png.rf.4c754d4572bad5d3070e39f5ab00448d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.4c754d4572bad5d3070e39f5ab00448d.jpg
#   inflating: screw_dataset/bad/002_png.rf.8286e997221b4ae75af9d4a971812765.jpg
#   inflating: __MACOSX/screw_dataset/bad/._002_png.rf.8286e997221b4ae75af9d4a971812765.jpg
#   inflating: screw_dataset/bad/000_png.rf.22875d4dc4b40c0f5ecc9eea46a92c02.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.22875d4dc4b40c0f5ecc9eea46a92c02.jpg
#   inflating: screw_dataset/bad/000_png.rf.95e9cb326d8d90df0c74f56f23f23512.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.95e9cb326d8d90df0c74f56f23f23512.jpg
#   inflating: screw_dataset/bad/002_png.rf.10b64b2adca0d5df8617fa46e5ae5cec.jpg
#   inflating: __MACOSX/screw_dataset/bad/._002_png.rf.10b64b2adca0d5df8617fa46e5ae5cec.jpg
#   inflating: screw_dataset/bad/004_png.rf.859951e355451926c293a49a9ae65695.jpg
#   inflating: __MACOSX/screw_dataset/bad/._004_png.rf.859951e355451926c293a49a9ae65695.jpg
#   inflating: screw_dataset/bad/019_png.rf.c8a10cd54f322142a6b5b8730b4dfd42.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.c8a10cd54f322142a6b5b8730b4dfd42.jpg
#   inflating: screw_dataset/bad/012_png.rf.fb4751065c1c68fe8b707e53b664803a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.fb4751065c1c68fe8b707e53b664803a.jpg
#   inflating: screw_dataset/bad/006_png.rf.377e4181b6d76eb2e44f7e602f61beb4.jpg
#   inflating: __MACOSX/screw_dataset/bad/._006_png.rf.377e4181b6d76eb2e44f7e602f61beb4.jpg
#   inflating: screw_dataset/bad/006_png.rf.be16227bad8a164fa19bebfb55f70d79.jpg
#   inflating: __MACOSX/screw_dataset/bad/._006_png.rf.be16227bad8a164fa19bebfb55f70d79.jpg
#   inflating: screw_dataset/bad/009_png.rf.953ed1b589b80347620023f0f86df445.jpg
#   inflating: __MACOSX/screw_dataset/bad/._009_png.rf.953ed1b589b80347620023f0f86df445.jpg
#   inflating: screw_dataset/bad/001_png.rf.66a7e6367f517cddfcacde961688c9fa.jpg
#   inflating: __MACOSX/screw_dataset/bad/._001_png.rf.66a7e6367f517cddfcacde961688c9fa.jpg
#   inflating: screw_dataset/bad/006_png.rf.7842d3654a2c6412542b4e963085c70c.jpg
#   inflating: __MACOSX/screw_dataset/bad/._006_png.rf.7842d3654a2c6412542b4e963085c70c.jpg
#   inflating: screw_dataset/bad/006_png.rf.c91480804e7a932f542567d5b0f0462b.jpg
#   inflating: __MACOSX/screw_dataset/bad/._006_png.rf.c91480804e7a932f542567d5b0f0462b.jpg
#   inflating: screw_dataset/bad/007_png.rf.d53e2296b03e0e8e010ee85b48d679c9.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.d53e2296b03e0e8e010ee85b48d679c9.jpg
#   inflating: screw_dataset/bad/005_png.rf.fd64e93c0a77ed9a505fdbb8a84a040a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.fd64e93c0a77ed9a505fdbb8a84a040a.jpg
#   inflating: screw_dataset/bad/007_png.rf.d2ee6eaf794ba815a1d37d4524e443c3.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.d2ee6eaf794ba815a1d37d4524e443c3.jpg
#   inflating: screw_dataset/bad/012_png.rf.c7a20f6c920690c55f311e1f89164c0d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.c7a20f6c920690c55f311e1f89164c0d.jpg
#   inflating: screw_dataset/bad/020_png.rf.f1c1e9347dfb617c18a80c2fed357334.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.f1c1e9347dfb617c18a80c2fed357334.jpg
#   inflating: screw_dataset/bad/010_png.rf.2200b36c91526b78d129d318721eb27f.jpg
#   inflating: __MACOSX/screw_dataset/bad/._010_png.rf.2200b36c91526b78d129d318721eb27f.jpg
#   inflating: screw_dataset/bad/012_png.rf.8476d2d32259b7521960d5b038877771.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.8476d2d32259b7521960d5b038877771.jpg
#   inflating: screw_dataset/bad/001_png.rf.112898c83477d014b990d8673c80717f.jpg
#   inflating: __MACOSX/screw_dataset/bad/._001_png.rf.112898c83477d014b990d8673c80717f.jpg
#   inflating: screw_dataset/bad/015_png.rf.32ca87983588b14483ec742552d3b3c5.jpg
#   inflating: __MACOSX/screw_dataset/bad/._015_png.rf.32ca87983588b14483ec742552d3b3c5.jpg
#   inflating: screw_dataset/bad/001_png.rf.ead283b3ee705b4ec038fd415552b2f0.jpg
#   inflating: __MACOSX/screw_dataset/bad/._001_png.rf.ead283b3ee705b4ec038fd415552b2f0.jpg
#   inflating: screw_dataset/bad/020_png.rf.bc1d8a583bfdb217fac2f64731e9771e.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.bc1d8a583bfdb217fac2f64731e9771e.jpg
#   inflating: screw_dataset/bad/015_png.rf.abca16fc65c5b27b8d97f9826063c6c0.jpg
#   inflating: __MACOSX/screw_dataset/bad/._015_png.rf.abca16fc65c5b27b8d97f9826063c6c0.jpg
#   inflating: screw_dataset/bad/004_png.rf.f78989783b58ad07420370d191a8e249.jpg
#   inflating: __MACOSX/screw_dataset/bad/._004_png.rf.f78989783b58ad07420370d191a8e249.jpg
#   inflating: screw_dataset/bad/013_png.rf.8a47b95962656fc3eb526a834de22d03.jpg
#   inflating: __MACOSX/screw_dataset/bad/._013_png.rf.8a47b95962656fc3eb526a834de22d03.jpg
#   inflating: screw_dataset/bad/014_png.rf.8a8a2194da389e496434370fcb6ca5d1.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.8a8a2194da389e496434370fcb6ca5d1.jpg
#   inflating: screw_dataset/bad/004_png.rf.684d076f2f4555b1267675d8d1b7c695.jpg
#   inflating: __MACOSX/screw_dataset/bad/._004_png.rf.684d076f2f4555b1267675d8d1b7c695.jpg
#   inflating: screw_dataset/bad/012_png.rf.1397aa9631e7cc40e1c087e437df7fbc.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.1397aa9631e7cc40e1c087e437df7fbc.jpg
#   inflating: screw_dataset/bad/018_png.rf.e6105b3a3a8e20d046fa31d7635870ce.jpg
#   inflating: __MACOSX/screw_dataset/bad/._018_png.rf.e6105b3a3a8e20d046fa31d7635870ce.jpg
#   inflating: screw_dataset/bad/021_png.rf.6bd9e38132b619dd984924c1e1290a79.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.6bd9e38132b619dd984924c1e1290a79.jpg
#   inflating: screw_dataset/bad/008_png.rf.285dc213ef1745a3b47dbb95da4601ad.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.285dc213ef1745a3b47dbb95da4601ad.jpg
#   inflating: screw_dataset/bad/024_png.rf.6409d8d9ff471898fe3df5e84331a725.jpg
#   inflating: __MACOSX/screw_dataset/bad/._024_png.rf.6409d8d9ff471898fe3df5e84331a725.jpg
#   inflating: screw_dataset/bad/008_png.rf.6a558b8fcb29955c1c3cd4f93e6d8fb1.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.6a558b8fcb29955c1c3cd4f93e6d8fb1.jpg
#   inflating: screw_dataset/bad/020_png.rf.58cc92be0d55ec29c036d3aff220cc29.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.58cc92be0d55ec29c036d3aff220cc29.jpg
#   inflating: screw_dataset/bad/009_png.rf.a6eaef9329f76ec9c937359d8a756921.jpg
#   inflating: __MACOSX/screw_dataset/bad/._009_png.rf.a6eaef9329f76ec9c937359d8a756921.jpg
#   inflating: screw_dataset/bad/019_png.rf.aacffd894e98230a24c97936be4ed641.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.aacffd894e98230a24c97936be4ed641.jpg
#   inflating: screw_dataset/bad/017_png.rf.18b6241e1c67407f2b30ea73ef41c042.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.18b6241e1c67407f2b30ea73ef41c042.jpg
#   inflating: screw_dataset/bad/001_png.rf.f2b48cfbbcc285e819851c56e06a261f.jpg
#   inflating: __MACOSX/screw_dataset/bad/._001_png.rf.f2b48cfbbcc285e819851c56e06a261f.jpg
#   inflating: screw_dataset/bad/015_png.rf.79f4fa24259d7f3eb799ab192f773d4a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._015_png.rf.79f4fa24259d7f3eb799ab192f773d4a.jpg
#   inflating: screw_dataset/bad/010_png.rf.20ae2324907434381c553c9c82d1d40d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._010_png.rf.20ae2324907434381c553c9c82d1d40d.jpg
#   inflating: screw_dataset/bad/020_png.rf.23c20961e768b993ca13dcaa572caf04.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.23c20961e768b993ca13dcaa572caf04.jpg
#   inflating: screw_dataset/bad/003_png.rf.c1b04ea327e62319dcdb857edc2f91f0.jpg
#   inflating: __MACOSX/screw_dataset/bad/._003_png.rf.c1b04ea327e62319dcdb857edc2f91f0.jpg
#   inflating: screw_dataset/bad/007_png.rf.f4dc311dac8ec607a8cec0ac8dee283f.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.f4dc311dac8ec607a8cec0ac8dee283f.jpg
#   inflating: screw_dataset/bad/009_png.rf.49067c5c67672bd5727c5c0ced6a6e61.jpg
#   inflating: __MACOSX/screw_dataset/bad/._009_png.rf.49067c5c67672bd5727c5c0ced6a6e61.jpg
#   inflating: screw_dataset/bad/000_png.rf.3f62fb50fe144f40fa1e79e715459232.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.3f62fb50fe144f40fa1e79e715459232.jpg
#   inflating: screw_dataset/bad/017_png.rf.36e2b645f9377d14af534c184311310a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.36e2b645f9377d14af534c184311310a.jpg
#   inflating: screw_dataset/bad/005_png.rf.40e6a6ff72ab6dd8c6366045835bd940.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.40e6a6ff72ab6dd8c6366045835bd940.jpg
#   inflating: screw_dataset/bad/002_png.rf.5d8c0885ff396e9df6befe7bcd3056f5.jpg
#   inflating: __MACOSX/screw_dataset/bad/._002_png.rf.5d8c0885ff396e9df6befe7bcd3056f5.jpg
#   inflating: screw_dataset/bad/012_png.rf.a87004c0915351c6899386e9768e8679.jpg
#   inflating: __MACOSX/screw_dataset/bad/._012_png.rf.a87004c0915351c6899386e9768e8679.jpg
#   inflating: screw_dataset/bad/011_png.rf.6cda08a58193b9386dcf143e40003088.jpg
#   inflating: __MACOSX/screw_dataset/bad/._011_png.rf.6cda08a58193b9386dcf143e40003088.jpg
#   inflating: screw_dataset/bad/017_png.rf.9f6067597be259aa89e8fe1835c75a82.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.9f6067597be259aa89e8fe1835c75a82.jpg
#   inflating: screw_dataset/bad/023_png.rf.6fad9dc5b5a7a96046df72457832daa9.jpg
#   inflating: __MACOSX/screw_dataset/bad/._023_png.rf.6fad9dc5b5a7a96046df72457832daa9.jpg
#   inflating: screw_dataset/bad/017_png.rf.872f6f101d7909ca9efee57e40dd638c.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.872f6f101d7909ca9efee57e40dd638c.jpg
#   inflating: screw_dataset/bad/011_png.rf.cca6e56adf768d121043f8a604ce7414.jpg
#   inflating: __MACOSX/screw_dataset/bad/._011_png.rf.cca6e56adf768d121043f8a604ce7414.jpg
#   inflating: screw_dataset/bad/013_png.rf.d55876451608f7bd0e1db7771f8d9d3d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._013_png.rf.d55876451608f7bd0e1db7771f8d9d3d.jpg
#   inflating: screw_dataset/bad/018_png.rf.4bc534c602e0d92028e39ffec1ee83db.jpg
#   inflating: __MACOSX/screw_dataset/bad/._018_png.rf.4bc534c602e0d92028e39ffec1ee83db.jpg
#   inflating: screw_dataset/bad/005_png.rf.2e84c413d05c8bc5dba4a046487ee823.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.2e84c413d05c8bc5dba4a046487ee823.jpg
#   inflating: screw_dataset/bad/009_png.rf.b819c8939a59300ca7db93bd815f1147.jpg
#   inflating: __MACOSX/screw_dataset/bad/._009_png.rf.b819c8939a59300ca7db93bd815f1147.jpg
#   inflating: screw_dataset/bad/018_png.rf.128e28d973378976e86587c95432b6ca.jpg
#   inflating: __MACOSX/screw_dataset/bad/._018_png.rf.128e28d973378976e86587c95432b6ca.jpg
#   inflating: screw_dataset/bad/000_png.rf.3671a876707bdaa523ee0d403606486b.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.3671a876707bdaa523ee0d403606486b.jpg
#   inflating: screw_dataset/bad/021_png.rf.acbe39a181c1298b1821e92a3a92de4d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.acbe39a181c1298b1821e92a3a92de4d.jpg
#   inflating: screw_dataset/bad/019_png.rf.8402e3ca2609ad62593b417f9181ea17.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.8402e3ca2609ad62593b417f9181ea17.jpg
#   inflating: screw_dataset/bad/002_png.rf.7c0b6e7dfc9b67025f47c2460dccd71a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._002_png.rf.7c0b6e7dfc9b67025f47c2460dccd71a.jpg
#   inflating: screw_dataset/bad/020_png.rf.47493d8da61c42c0e88f65bdb46a31f3.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.47493d8da61c42c0e88f65bdb46a31f3.jpg
#   inflating: screw_dataset/bad/005_png.rf.9ccc9299911c2440686fbf14cbeb1ac2.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.9ccc9299911c2440686fbf14cbeb1ac2.jpg
#   inflating: screw_dataset/bad/010_png.rf.49e214452922e22b40fe37eae05704b0.jpg
#   inflating: __MACOSX/screw_dataset/bad/._010_png.rf.49e214452922e22b40fe37eae05704b0.jpg
#   inflating: screw_dataset/bad/021_png.rf.1165c648102c5473d10f0e823f069f02.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.1165c648102c5473d10f0e823f069f02.jpg
#   inflating: screw_dataset/bad/011_png.rf.55044aaaa24f49d50031a59b4f0f5c32.jpg
#   inflating: __MACOSX/screw_dataset/bad/._011_png.rf.55044aaaa24f49d50031a59b4f0f5c32.jpg
#   inflating: screw_dataset/bad/017_png.rf.1716da12d29208c8ffd4cc3c336f46ac.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.1716da12d29208c8ffd4cc3c336f46ac.jpg
#   inflating: screw_dataset/bad/023_png.rf.35d14e5556960df2915ab9b1de80d310.jpg
#   inflating: __MACOSX/screw_dataset/bad/._023_png.rf.35d14e5556960df2915ab9b1de80d310.jpg
#   inflating: screw_dataset/bad/005_png.rf.fd76dbd71711a6957892b3f169e7bfe1.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.fd76dbd71711a6957892b3f169e7bfe1.jpg
#   inflating: screw_dataset/bad/018_png.rf.2bff3045304a3edf272f1adfeb669b4a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._018_png.rf.2bff3045304a3edf272f1adfeb669b4a.jpg
#   inflating: screw_dataset/bad/007_png.rf.88df8d092f8587526b94e4f65cf78fd7.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.88df8d092f8587526b94e4f65cf78fd7.jpg
#   inflating: screw_dataset/bad/004_png.rf.64b9cd524f0eced21055dfcd558421b0.jpg
#   inflating: __MACOSX/screw_dataset/bad/._004_png.rf.64b9cd524f0eced21055dfcd558421b0.jpg
#   inflating: screw_dataset/bad/020_png.rf.13df76e3fd65a9240554859e26a46936.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.13df76e3fd65a9240554859e26a46936.jpg
#   inflating: screw_dataset/bad/010_png.rf.6c90912a0f956b3e80da0327212b975d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._010_png.rf.6c90912a0f956b3e80da0327212b975d.jpg
#   inflating: screw_dataset/bad/010_png.rf.3f5e4a227f3261356a686d956b465331.jpg
#   inflating: __MACOSX/screw_dataset/bad/._010_png.rf.3f5e4a227f3261356a686d956b465331.jpg
#   inflating: screw_dataset/bad/004_png.rf.f99a15a7032dc5cfbbc1d72609ee0f94.jpg
#   inflating: __MACOSX/screw_dataset/bad/._004_png.rf.f99a15a7032dc5cfbbc1d72609ee0f94.jpg
#   inflating: screw_dataset/bad/015_png.rf.76cbb27ac97cff988c1add5a79ac929a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._015_png.rf.76cbb27ac97cff988c1add5a79ac929a.jpg
#   inflating: screw_dataset/bad/019_png.rf.58be09d99803f669ff951924ae633d9e.jpg
#   inflating: __MACOSX/screw_dataset/bad/._019_png.rf.58be09d99803f669ff951924ae633d9e.jpg
#   inflating: screw_dataset/bad/000_png.rf.6576630d03abce02c855fdd9ee9f4321.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.6576630d03abce02c855fdd9ee9f4321.jpg
#   inflating: screw_dataset/bad/005_png.rf.90b57502db3f02e8c0c828156a0ab1d4.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.90b57502db3f02e8c0c828156a0ab1d4.jpg
#   inflating: screw_dataset/bad/010_png.rf.ac020e449444041f48c5c945116d4ee3.jpg
#   inflating: __MACOSX/screw_dataset/bad/._010_png.rf.ac020e449444041f48c5c945116d4ee3.jpg
#   inflating: screw_dataset/bad/000_png.rf.150d97f3842bae43d25e38ddd985ce0d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.150d97f3842bae43d25e38ddd985ce0d.jpg
#   inflating: screw_dataset/bad/011_png.rf.2636560166ded82da25230be0cb802eb.jpg
#   inflating: __MACOSX/screw_dataset/bad/._011_png.rf.2636560166ded82da25230be0cb802eb.jpg
#   inflating: screw_dataset/bad/003_png.rf.df0d5d8565b77f30c91486dee3ec2694.jpg
#   inflating: __MACOSX/screw_dataset/bad/._003_png.rf.df0d5d8565b77f30c91486dee3ec2694.jpg
#   inflating: screw_dataset/bad/017_png.rf.ae2f700c2f97a73e5fa58f41b36eee25.jpg
#   inflating: __MACOSX/screw_dataset/bad/._017_png.rf.ae2f700c2f97a73e5fa58f41b36eee25.jpg
#   inflating: screw_dataset/bad/006_png.rf.c13a364cc262b36d021c69ab2a8533dc.jpg
#   inflating: __MACOSX/screw_dataset/bad/._006_png.rf.c13a364cc262b36d021c69ab2a8533dc.jpg
#   inflating: screw_dataset/bad/007_png.rf.17bf4e80d341e37775e4a990464188c1.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.17bf4e80d341e37775e4a990464188c1.jpg
#   inflating: screw_dataset/bad/018_png.rf.ef572874e50de408e05fd3befa9abd9d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._018_png.rf.ef572874e50de408e05fd3befa9abd9d.jpg
#   inflating: screw_dataset/bad/004_png.rf.fb5a4b7b1be2b6599651ec68f25a43e4.jpg
#   inflating: __MACOSX/screw_dataset/bad/._004_png.rf.fb5a4b7b1be2b6599651ec68f25a43e4.jpg
#   inflating: screw_dataset/bad/002_png.rf.fa7439330e53e6346578d34aa393baf2.jpg
#   inflating: __MACOSX/screw_dataset/bad/._002_png.rf.fa7439330e53e6346578d34aa393baf2.jpg
#   inflating: screw_dataset/bad/020_png.rf.5b632730f320f118e781f8100cfc5d2a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.5b632730f320f118e781f8100cfc5d2a.jpg
#   inflating: screw_dataset/bad/010_png.rf.7775bba23cf13789261c272b42ecc6a5.jpg
#   inflating: __MACOSX/screw_dataset/bad/._010_png.rf.7775bba23cf13789261c272b42ecc6a5.jpg
#   inflating: screw_dataset/bad/003_png.rf.ececc51e19f5f316f772f3d37cce177e.jpg
#   inflating: __MACOSX/screw_dataset/bad/._003_png.rf.ececc51e19f5f316f772f3d37cce177e.jpg
#   inflating: screw_dataset/bad/022_png.rf.c466377c2c5460931180ab59451c72cd.jpg
#   inflating: __MACOSX/screw_dataset/bad/._022_png.rf.c466377c2c5460931180ab59451c72cd.jpg
#   inflating: screw_dataset/bad/009_png.rf.4ec96d7388b894b7d173a4689b560b5b.jpg
#   inflating: __MACOSX/screw_dataset/bad/._009_png.rf.4ec96d7388b894b7d173a4689b560b5b.jpg
#   inflating: screw_dataset/bad/011_png.rf.4438fdb9cca57497507ae3520c29476d.jpg
#   inflating: __MACOSX/screw_dataset/bad/._011_png.rf.4438fdb9cca57497507ae3520c29476d.jpg
#   inflating: screw_dataset/bad/002_png.rf.4aecc26a823b5a1ab391744f6c816577.jpg
#   inflating: __MACOSX/screw_dataset/bad/._002_png.rf.4aecc26a823b5a1ab391744f6c816577.jpg
#   inflating: screw_dataset/bad/013_png.rf.34930f516b16f2dd6150d5b889883271.jpg
#   inflating: __MACOSX/screw_dataset/bad/._013_png.rf.34930f516b16f2dd6150d5b889883271.jpg
#   inflating: screw_dataset/bad/020_png.rf.20e65f6de9a00c9f1b3181a6e2054b1a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._020_png.rf.20e65f6de9a00c9f1b3181a6e2054b1a.jpg
#   inflating: screw_dataset/bad/002_png.rf.84a86e9ba7e7e01c68501521db75d5cd.jpg
#   inflating: __MACOSX/screw_dataset/bad/._002_png.rf.84a86e9ba7e7e01c68501521db75d5cd.jpg
#   inflating: screw_dataset/bad/007_png.rf.a99c262cf798c7fd2ec406b941878128.jpg
#   inflating: __MACOSX/screw_dataset/bad/._007_png.rf.a99c262cf798c7fd2ec406b941878128.jpg
#   inflating: screw_dataset/bad/001_png.rf.94008a755559d4528cacccd3c93d5f9b.jpg
#   inflating: __MACOSX/screw_dataset/bad/._001_png.rf.94008a755559d4528cacccd3c93d5f9b.jpg
#   inflating: screw_dataset/bad/015_png.rf.45f39c319ab53b4d970eab87859c8fc0.jpg
#   inflating: __MACOSX/screw_dataset/bad/._015_png.rf.45f39c319ab53b4d970eab87859c8fc0.jpg
#   inflating: screw_dataset/bad/008_png.rf.ade18e858a179205ee1fbc155a67670a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.ade18e858a179205ee1fbc155a67670a.jpg
#   inflating: screw_dataset/bad/011_png.rf.d76328d363379a7438bb03da0464e4a5.jpg
#   inflating: __MACOSX/screw_dataset/bad/._011_png.rf.d76328d363379a7438bb03da0464e4a5.jpg
#   inflating: screw_dataset/bad/022_png.rf.7f681cda4bcb49389edc6431152b2be7.jpg
#   inflating: __MACOSX/screw_dataset/bad/._022_png.rf.7f681cda4bcb49389edc6431152b2be7.jpg
#   inflating: screw_dataset/bad/000_png.rf.23a40510a9136ea9ee3c91214536fe9a.jpg
#   inflating: __MACOSX/screw_dataset/bad/._000_png.rf.23a40510a9136ea9ee3c91214536fe9a.jpg
#   inflating: screw_dataset/bad/021_png.rf.363b4aa9fee463a07f26dfc355e4eda2.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.363b4aa9fee463a07f26dfc355e4eda2.jpg
#   inflating: screw_dataset/bad/009_png.rf.9e0e1f131934e562d8f4ccc591763e74.jpg
#   inflating: __MACOSX/screw_dataset/bad/._009_png.rf.9e0e1f131934e562d8f4ccc591763e74.jpg
#   inflating: screw_dataset/bad/001_png.rf.a65675f4d4eecade86f77fe7d0a8edfa.jpg
#   inflating: __MACOSX/screw_dataset/bad/._001_png.rf.a65675f4d4eecade86f77fe7d0a8edfa.jpg
#   inflating: screw_dataset/bad/008_png.rf.6cdc165cea4bfbe57cdda0688e424265.jpg
#   inflating: __MACOSX/screw_dataset/bad/._008_png.rf.6cdc165cea4bfbe57cdda0688e424265.jpg
#   inflating: screw_dataset/bad/016_png.rf.ab17816bce13045a8a296abb6a6cb93f.jpg
#   inflating: __MACOSX/screw_dataset/bad/._016_png.rf.ab17816bce13045a8a296abb6a6cb93f.jpg
#   inflating: screw_dataset/bad/010_png.rf.fb0717ea83579722abea1a98bf93cbc8.jpg
#   inflating: __MACOSX/screw_dataset/bad/._010_png.rf.fb0717ea83579722abea1a98bf93cbc8.jpg
#   inflating: screw_dataset/bad/001_png.rf.3576873db1c0902ccdfd6cad4001aadd.jpg
#   inflating: __MACOSX/screw_dataset/bad/._001_png.rf.3576873db1c0902ccdfd6cad4001aadd.jpg
#   inflating: screw_dataset/bad/005_png.rf.4895e8313ae2a2961eeb66d0815ce104.jpg
#   inflating: __MACOSX/screw_dataset/bad/._005_png.rf.4895e8313ae2a2961eeb66d0815ce104.jpg
#   inflating: screw_dataset/bad/014_png.rf.0930176c676c10c90468c4b5d1dfb218.jpg
#   inflating: __MACOSX/screw_dataset/bad/._014_png.rf.0930176c676c10c90468c4b5d1dfb218.jpg
#   inflating: screw_dataset/bad/002_png.rf.475e1b995b1ed6e445c821f16893fefc.jpg
#   inflating: __MACOSX/screw_dataset/bad/._002_png.rf.475e1b995b1ed6e445c821f16893fefc.jpg
#   inflating: screw_dataset/bad/001_png.rf.dbe2e16fe0c55e0473f60252cdaa90ca.jpg
#   inflating: __MACOSX/screw_dataset/bad/._001_png.rf.dbe2e16fe0c55e0473f60252cdaa90ca.jpg
#   inflating: screw_dataset/bad/021_png.rf.e4dd0fd653cf63e06fc1ee07b80dcf90.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.e4dd0fd653cf63e06fc1ee07b80dcf90.jpg
#   inflating: screw_dataset/bad/021_png.rf.cfe8bd40dce109433c9a1f1e64a03ebb.jpg
#   inflating: __MACOSX/screw_dataset/bad/._021_png.rf.cfe8bd40dce109433c9a1f1e64a03ebb.jpg
#   inflating: screw_dataset/bad/004_png.rf.82636c63d0c9c08305af79240fdef69e.jpg
# ...
#   inflating: screw_dataset/good/220_png.rf.99cdb1213c0f770b20b1d12ee4952373.jpg
#   inflating: __MACOSX/screw_dataset/good/._220_png.rf.99cdb1213c0f770b20b1d12ee4952373.jpg
#   inflating: screw_dataset/good/232_png.rf.2a6d91fe979087826b9f2f858b19410e.jpg
#   inflating: __MACOSX/screw_dataset/good/._232_png.rf.2a6d91fe979087826b9f2f858b19410e.jpg
#   inflating: screw_dataset/good/175_png.rf.303d5fbd8173b2329d1d89e731e8fbfa.jpg
#   inflating: __MACOSX/screw_dataset/good/._175_png.rf.303d5fbd8173b2329d1d89e731e8fbfa.jpg
#   inflating: screw_dataset/good/019_png.rf.9b4ce08a2a5719023414b9b764b33b22.jpg
#   inflating: __MACOSX/screw_dataset/good/._019_png.rf.9b4ce08a2a5719023414b9b764b33b22.jpg
#   inflating: screw_dataset/good/115_png.rf.6603191bb8f1d00f46ac7bedae31a473.jpg
#   inflating: __MACOSX/screw_dataset/good/._115_png.rf.6603191bb8f1d00f46ac7bedae31a473.jpg
#   inflating: screw_dataset/good/172_png.rf.f63c67edcf34f036aaf3ba53ba851576.jpg
#   inflating: __MACOSX/screw_dataset/good/._172_png.rf.f63c67edcf34f036aaf3ba53ba851576.jpg
#   inflating: screw_dataset/good/018_png.rf.92f43e87049568bddbde84a7fe286dcb.jpg
#   inflating: __MACOSX/screw_dataset/good/._018_png.rf.92f43e87049568bddbde84a7fe286dcb.jpg
#   inflating: screw_dataset/good/011_png.rf.114d27f84eb2a4b64fee46032660c2fd.jpg
#   inflating: __MACOSX/screw_dataset/good/._011_png.rf.114d27f84eb2a4b64fee46032660c2fd.jpg
#   inflating: screw_dataset/good/034_png.rf.d421c3c667160f77285bf8c1b2c073e6.jpg
#   inflating: __MACOSX/screw_dataset/good/._034_png.rf.d421c3c667160f77285bf8c1b2c073e6.jpg
#   inflating: screw_dataset/good/211_png.rf.6017a9e84fca0a5e366120e98ca96c63.jpg
#   inflating: __MACOSX/screw_dataset/good/._211_png.rf.6017a9e84fca0a5e366120e98ca96c63.jpg
#   inflating: screw_dataset/good/182_png.rf.331f80ecd77956c97d18826d30da1daa.jpg
#   inflating: __MACOSX/screw_dataset/good/._182_png.rf.331f80ecd77956c97d18826d30da1daa.jpg
#   inflating: screw_dataset/good/085_png.rf.bb267f3348b1b98402ea99a89209b05a.jpg
#   inflating: __MACOSX/screw_dataset/good/._085_png.rf.bb267f3348b1b98402ea99a89209b05a.jpg
#   inflating: screw_dataset/good/083_png.rf.05f90dc0a4131184ead4959914d0ec25.jpg
#   inflating: __MACOSX/screw_dataset/good/._083_png.rf.05f90dc0a4131184ead4959914d0ec25.jpg
#   inflating: screw_dataset/good/301_png.rf.91f1dae3a2fb1ad4d71fa089f5d39b17.jpg
#   inflating: __MACOSX/screw_dataset/good/._301_png.rf.91f1dae3a2fb1ad4d71fa089f5d39b17.jpg
#   inflating: screw_dataset/good/212_png.rf.d9dd62d141556b60a3dedfd4ab134c0e.jpg
#   inflating: __MACOSX/screw_dataset/good/._212_png.rf.d9dd62d141556b60a3dedfd4ab134c0e.jpg
#   inflating: screw_dataset/good/030_png.rf.365305d450525cbfe6e53763b96c7e9e.jpg
#   inflating: __MACOSX/screw_dataset/good/._030_png.rf.365305d450525cbfe6e53763b96c7e9e.jpg
#   inflating: screw_dataset/good/158_png.rf.ad305fdaf5cca19cc06ce4da30548b6c.jpg
#   inflating: __MACOSX/screw_dataset/good/._158_png.rf.ad305fdaf5cca19cc06ce4da30548b6c.jpg
#   inflating: screw_dataset/good/145_png.rf.f47a74701704b48b0ee124bc649dccb8.jpg
#   inflating: __MACOSX/screw_dataset/good/._145_png.rf.f47a74701704b48b0ee124bc649dccb8.jpg
#   inflating: screw_dataset/good/204_png.rf.4a3a97a802dd26db7d5317fa226d793f.jpg
#   inflating: __MACOSX/screw_dataset/good/._204_png.rf.4a3a97a802dd26db7d5317fa226d793f.jpg
#   inflating: screw_dataset/good/031_png.rf.464dff935d9ed965f5aa64ec1205f77d.jpg
#   inflating: __MACOSX/screw_dataset/good/._031_png.rf.464dff935d9ed965f5aa64ec1205f77d.jpg
#   inflating: screw_dataset/good/265_png.rf.6f1793451f46d2633913bc7d62153447.jpg
#   inflating: __MACOSX/screw_dataset/good/._265_png.rf.6f1793451f46d2633913bc7d62153447.jpg
#   inflating: screw_dataset/good/044_png.rf.a6ca18b8477f611e873c78f0ed65b7fb.jpg
#   inflating: __MACOSX/screw_dataset/good/._044_png.rf.a6ca18b8477f611e873c78f0ed65b7fb.jpg
#   inflating: screw_dataset/good/149_png.rf.3ca81c11a9e07c8d61ee62064deef246.jpg
#   inflating: __MACOSX/screw_dataset/good/._149_png.rf.3ca81c11a9e07c8d61ee62064deef246.jpg
#   inflating: screw_dataset/good/216_png.rf.7c564d8a53d7589d037b22068ca01bcd.jpg
#   inflating: __MACOSX/screw_dataset/good/._216_png.rf.7c564d8a53d7589d037b22068ca01bcd.jpg
#   inflating: screw_dataset/good/053_png.rf.3e33e911d6bd6f1b8458a8387f257456.jpg
#   inflating: __MACOSX/screw_dataset/good/._053_png.rf.3e33e911d6bd6f1b8458a8387f257456.jpg
#   inflating: screw_dataset/good/242_png.rf.756fc403d29bbfe26dc1041e655a473d.jpg
#   inflating: __MACOSX/screw_dataset/good/._242_png.rf.756fc403d29bbfe26dc1041e655a473d.jpg
#   inflating: screw_dataset/good/170_png.rf.73a4c3adecf20c2943321ff8222087af.jpg
#   inflating: __MACOSX/screw_dataset/good/._170_png.rf.73a4c3adecf20c2943321ff8222087af.jpg
#   inflating: screw_dataset/good/006_png.rf.8d5e5c0696766057f9fcc6f54b4d5fd4.jpg
#   inflating: __MACOSX/screw_dataset/good/._006_png.rf.8d5e5c0696766057f9fcc6f54b4d5fd4.jpg
#   inflating: screw_dataset/good/295_png.rf.c1e1cd348f05032431ca93c294af5357.jpg
#   inflating: __MACOSX/screw_dataset/good/._295_png.rf.c1e1cd348f05032431ca93c294af5357.jpg
#   inflating: screw_dataset/good/272_png.rf.3fffa9981cb22f2124589fe8096f469a.jpg
#   inflating: __MACOSX/screw_dataset/good/._272_png.rf.3fffa9981cb22f2124589fe8096f469a.jpg
#   inflating: screw_dataset/good/286_png.rf.d1ad87b7277b10c58816ecad01ead902.jpg
#   inflating: __MACOSX/screw_dataset/good/._286_png.rf.d1ad87b7277b10c58816ecad01ead902.jpg
#   inflating: screw_dataset/good/084_png.rf.f5cd95fd5213af90b054d9f9c1f4147d.jpg
#   inflating: __MACOSX/screw_dataset/good/._084_png.rf.f5cd95fd5213af90b054d9f9c1f4147d.jpg
#   inflating: screw_dataset/good/134_png.rf.db95be6c121c6227f07efe9d03a7e5ee.jpg
#   inflating: __MACOSX/screw_dataset/good/._134_png.rf.db95be6c121c6227f07efe9d03a7e5ee.jpg
#   inflating: screw_dataset/good/193_png.rf.d63c3cfcd9cc814e8dd7d90e6164f76f.jpg
#   inflating: __MACOSX/screw_dataset/good/._193_png.rf.d63c3cfcd9cc814e8dd7d90e6164f76f.jpg
#   inflating: screw_dataset/good/309_png.rf.c4c4b08053f9452f84ae1e3bb8a00fad.jpg
#   inflating: __MACOSX/screw_dataset/good/._309_png.rf.c4c4b08053f9452f84ae1e3bb8a00fad.jpg
#   inflating: screw_dataset/good/065_png.rf.7dc5ef0cb943bdc1f70f8b3ca09f24ce.jpg
#   inflating: __MACOSX/screw_dataset/good/._065_png.rf.7dc5ef0cb943bdc1f70f8b3ca09f24ce.jpg
#   inflating: screw_dataset/good/062_png.rf.c39defe34e135bc8076b5d0412bb6355.jpg
#   inflating: __MACOSX/screw_dataset/good/._062_png.rf.c39defe34e135bc8076b5d0412bb6355.jpg
#   inflating: screw_dataset/good/181_png.rf.54f82d401773f2b37949f9024e8775c7.jpg
#   inflating: __MACOSX/screw_dataset/good/._181_png.rf.54f82d401773f2b37949f9024e8775c7.jpg
#   inflating: screw_dataset/good/257_png.rf.c1971123128a3e2f577f3006c5b72d0a.jpg
#   inflating: __MACOSX/screw_dataset/good/._257_png.rf.c1971123128a3e2f577f3006c5b72d0a.jpg
#   inflating: screw_dataset/good/318_png.rf.8b4791dfb4e1b9c002434f36d7814ea2.jpg
#   inflating: __MACOSX/screw_dataset/good/._318_png.rf.8b4791dfb4e1b9c002434f36d7814ea2.jpg
#   inflating: screw_dataset/good/157_png.rf.958817e78d6fed7555281b8e4af6156f.jpg
#   inflating: __MACOSX/screw_dataset/good/._157_png.rf.958817e78d6fed7555281b8e4af6156f.jpg
#   inflating: screw_dataset/good/120_png.rf.fe7150605feadd146e8ca39cca4c31e2.jpg
#   inflating: __MACOSX/screw_dataset/good/._120_png.rf.fe7150605feadd146e8ca39cca4c31e2.jpg
#   inflating: screw_dataset/good/161_png.rf.cf0ed85199e38951ba3d660a36ada374.jpg
#   inflating: __MACOSX/screw_dataset/good/._161_png.rf.cf0ed85199e38951ba3d660a36ada374.jpg
#   inflating: screw_dataset/good/255_png.rf.8c7e8185197d37598dc4ef6b5094994a.jpg
#   inflating: __MACOSX/screw_dataset/good/._255_png.rf.8c7e8185197d37598dc4ef6b5094994a.jpg
#   inflating: screw_dataset/good/108_png.rf.4030fd7f0be83ba8d7b82c8e8c1419c7.jpg
#   inflating: __MACOSX/screw_dataset/good/._108_png.rf.4030fd7f0be83ba8d7b82c8e8c1419c7.jpg
#   inflating: screw_dataset/good/008_png.rf.9e9e077e66d5993d4a5b635944fec20c.jpg
#   inflating: __MACOSX/screw_dataset/good/._008_png.rf.9e9e077e66d5993d4a5b635944fec20c.jpg
#   inflating: screw_dataset/good/015_png.rf.4e3f883d7d818296a2d3d9444a85ded3.jpg
#   inflating: __MACOSX/screw_dataset/good/._015_png.rf.4e3f883d7d818296a2d3d9444a85ded3.jpg
#   inflating: screw_dataset/good/086_png.rf.64a79366e7ee8b77b6a2758502403ea5.jpg
#   inflating: __MACOSX/screw_dataset/good/._086_png.rf.64a79366e7ee8b77b6a2758502403ea5.jpg
#   inflating: screw_dataset/good/040_png.rf.5d0aa8e15b49800b7d71e0ad629e1e4e.jpg
#   inflating: __MACOSX/screw_dataset/good/._040_png.rf.5d0aa8e15b49800b7d71e0ad629e1e4e.jpg
#   inflating: screw_dataset/good/230_png.rf.6baeb67f04bfa43255b6abc6e4086c26.jpg
#   inflating: __MACOSX/screw_dataset/good/._230_png.rf.6baeb67f04bfa43255b6abc6e4086c26.jpg
#   inflating: screw_dataset/good/145_png.rf.f81a438d914b44ce5aef600123a731e5.jpg
#   inflating: __MACOSX/screw_dataset/good/._145_png.rf.f81a438d914b44ce5aef600123a731e5.jpg
#   inflating: screw_dataset/good/238_png.rf.b091d24bbbf980a26be075031d244416.jpg
#   inflating: __MACOSX/screw_dataset/good/._238_png.rf.b091d24bbbf980a26be075031d244416.jpg
#   inflating: screw_dataset/good/225_png.rf.6ce1f6c2b5f9da98fb2eb38d7407c5bf.jpg
#   inflating: __MACOSX/screw_dataset/good/._225_png.rf.6ce1f6c2b5f9da98fb2eb38d7407c5bf.jpg
#   inflating: screw_dataset/good/042_png.rf.ea84a2057864c0be4b8a3b6fab022b97.jpg
#   inflating: __MACOSX/screw_dataset/good/._042_png.rf.ea84a2057864c0be4b8a3b6fab022b97.jpg
#   inflating: screw_dataset/good/026_png.rf.507eedc620c35cefe20fc327c9da0e35.jpg
#   inflating: __MACOSX/screw_dataset/good/._026_png.rf.507eedc620c35cefe20fc327c9da0e35.jpg
#   inflating: screw_dataset/good/137_png.rf.8aab9589004a4fd19d58d611853d692a.jpg
#   inflating: __MACOSX/screw_dataset/good/._137_png.rf.8aab9589004a4fd19d58d611853d692a.jpg
#   inflating: screw_dataset/good/061_png.rf.62cdb6078efd19d5f999aa7af9879468.jpg
#   inflating: __MACOSX/screw_dataset/good/._061_png.rf.62cdb6078efd19d5f999aa7af9879468.jpg
#   inflating: screw_dataset/good/062_png.rf.7ae773c456c7beffc2025e02fd4e32ae.jpg
#   inflating: __MACOSX/screw_dataset/good/._062_png.rf.7ae773c456c7beffc2025e02fd4e32ae.jpg
#   inflating: screw_dataset/good/296_png.rf.9c7d54f1bbfa3e402d42ff04aedcd4da.jpg
#   inflating: __MACOSX/screw_dataset/good/._296_png.rf.9c7d54f1bbfa3e402d42ff04aedcd4da.jpg
#   inflating: screw_dataset/good/005_png.rf.851cf790c9df9f05cceb5f2a509891d8.jpg
#   inflating: __MACOSX/screw_dataset/good/._005_png.rf.851cf790c9df9f05cceb5f2a509891d8.jpg
#   inflating: screw_dataset/good/196_png.rf.cbc878a3b31fa35a019c25b9b4204f7a.jpg
#   inflating: __MACOSX/screw_dataset/good/._196_png.rf.cbc878a3b31fa35a019c25b9b4204f7a.jpg
#   inflating: screw_dataset/good/139_png.rf.11156d1f644e3ca11ac71bfdd6f6b059.jpg
#   inflating: __MACOSX/screw_dataset/good/._139_png.rf.11156d1f644e3ca11ac71bfdd6f6b059.jpg
#   inflating: screw_dataset/good/071_png.rf.dad203298541adf1ae6538f3ecad6086.jpg
#   inflating: __MACOSX/screw_dataset/good/._071_png.rf.dad203298541adf1ae6538f3ecad6086.jpg
#   inflating: screw_dataset/good/115_png.rf.f7a8880d5a4810715fb8c937ddeed931.jpg
#   inflating: __MACOSX/screw_dataset/good/._115_png.rf.f7a8880d5a4810715fb8c937ddeed931.jpg
#   inflating: screw_dataset/good/304_png.rf.ea701e836b2f52fee6f161ff4bca48eb.jpg
#   inflating: __MACOSX/screw_dataset/good/._304_png.rf.ea701e836b2f52fee6f161ff4bca48eb.jpg
#   inflating: screw_dataset/good/002_png.rf.f3644cdb671777f5651cd40f9328f225.jpg
#   inflating: __MACOSX/screw_dataset/good/._002_png.rf.f3644cdb671777f5651cd40f9328f225.jpg
#   inflating: screw_dataset/good/206_png.rf.fd3cae0c7db1460dd1d1fa4f7a3755b5.jpg
#   inflating: __MACOSX/screw_dataset/good/._206_png.rf.fd3cae0c7db1460dd1d1fa4f7a3755b5.jpg
#   inflating: screw_dataset/good/317_png.rf.d6f8a30bfa93de4a38f48d9ccc7cd865.jpg
#   inflating: __MACOSX/screw_dataset/good/._317_png.rf.d6f8a30bfa93de4a38f48d9ccc7cd865.jpg
#   inflating: screw_dataset/good/109_png.rf.56163da92ca333af8d444cd7cc8e17ea.jpg
#   inflating: __MACOSX/screw_dataset/good/._109_png.rf.56163da92ca333af8d444cd7cc8e17ea.jpg
#   inflating: screw_dataset/good/026_png.rf.7312eb5d946bbd1161eb2f4e43007576.jpg
#   inflating: __MACOSX/screw_dataset/good/._026_png.rf.7312eb5d946bbd1161eb2f4e43007576.jpg
#   inflating: screw_dataset/good/271_png.rf.853547b4f70de615860bf0a9b27de6e4.jpg
#   inflating: __MACOSX/screw_dataset/good/._271_png.rf.853547b4f70de615860bf0a9b27de6e4.jpg
#   inflating: screw_dataset/good/046_png.rf.8566eb877f7425a980a123a4bd1d3d1e.jpg
#   inflating: __MACOSX/screw_dataset/good/._046_png.rf.8566eb877f7425a980a123a4bd1d3d1e.jpg
#   inflating: screw_dataset/good/148_png.rf.2089baf58c2d9b3beac201e13d2ac676.jpg
#   inflating: __MACOSX/screw_dataset/good/._148_png.rf.2089baf58c2d9b3beac201e13d2ac676.jpg
#   inflating: screw_dataset/good/197_png.rf.204395bc9c28bbd0486158e5e8cc07a2.jpg
#   inflating: __MACOSX/screw_dataset/good/._197_png.rf.204395bc9c28bbd0486158e5e8cc07a2.jpg
#   inflating: screw_dataset/good/179_png.rf.77f947e35edca9bf881e563b686ad20f.jpg
#   inflating: __MACOSX/screw_dataset/good/._179_png.rf.77f947e35edca9bf881e563b686ad20f.jpg
#   inflating: screw_dataset/good/006_png.rf.4585de8b27690a9081a56f9f48612884.jpg
#   inflating: __MACOSX/screw_dataset/good/._006_png.rf.4585de8b27690a9081a56f9f48612884.jpg
#   inflating: screw_dataset/good/033_png.rf.5cb4e4aeda559e50830aa4c3fc73831a.jpg
#   inflating: __MACOSX/screw_dataset/good/._033_png.rf.5cb4e4aeda559e50830aa4c3fc73831a.jpg
#   inflating: screw_dataset/good/107_png.rf.4836107ee5c078c6301557814766774a.jpg
#   inflating: __MACOSX/screw_dataset/good/._107_png.rf.4836107ee5c078c6301557814766774a.jpg
#   inflating: screw_dataset/good/113_png.rf.a4b1bdfff6a2f04c6d7a4861d5bd3eff.jpg
#   inflating: __MACOSX/screw_dataset/good/._113_png.rf.a4b1bdfff6a2f04c6d7a4861d5bd3eff.jpg
#   inflating: screw_dataset/good/015_png.rf.0f96ee7d280cbb126da91f938f5b1ec2.jpg
#   inflating: __MACOSX/screw_dataset/good/._015_png.rf.0f96ee7d280cbb126da91f938f5b1ec2.jpg
#   inflating: screw_dataset/good/034_png.rf.73ddc5f893bdfd6e696553e102c9fd79.jpg
#   inflating: __MACOSX/screw_dataset/good/._034_png.rf.73ddc5f893bdfd6e696553e102c9fd79.jpg
#   inflating: screw_dataset/good/012_png.rf.3da44a820dded15e55c492089e2789a1.jpg
#   inflating: __MACOSX/screw_dataset/good/._012_png.rf.3da44a820dded15e55c492089e2789a1.jpg
#   inflating: screw_dataset/good/063_png.rf.a9576ef0266408ae1a27fd74148d4168.jpg
#   inflating: __MACOSX/screw_dataset/good/._063_png.rf.a9576ef0266408ae1a27fd74148d4168.jpg
#   inflating: screw_dataset/good/010_png.rf.c5cdc2b20c2a5f44dec6b7edef6f991f.jpg
#   inflating: __MACOSX/screw_dataset/good/._010_png.rf.c5cdc2b20c2a5f44dec6b7edef6f991f.jpg
#   inflating: screw_dataset/good/274_png.rf.90716394665a34d9a4803888264ad9b0.jpg
#   inflating: __MACOSX/screw_dataset/good/._274_png.rf.90716394665a34d9a4803888264ad9b0.jpg
#   inflating: screw_dataset/good/158_png.rf.3ea67b9d5d047b844998924aaa0df8a4.jpg
#   inflating: __MACOSX/screw_dataset/good/._158_png.rf.3ea67b9d5d047b844998924aaa0df8a4.jpg
#   inflating: screw_dataset/good/091_png.rf.f5652c35d282da04ee32270a7b72a45a.jpg
#   inflating: __MACOSX/screw_dataset/good/._091_png.rf.f5652c35d282da04ee32270a7b72a45a.jpg
#   inflating: screw_dataset/good/243_png.rf.671969975df0ad9a889029b79f61122d.jpg
#   inflating: __MACOSX/screw_dataset/good/._243_png.rf.671969975df0ad9a889029b79f61122d.jpg
#   inflating: screw_dataset/good/144_png.rf.f78b6b48c9b5654eae63ca4cecd396a3.jpg
#   inflating: __MACOSX/screw_dataset/good/._144_png.rf.f78b6b48c9b5654eae63ca4cecd396a3.jpg
#   inflating: screw_dataset/good/056_png.rf.913e4a3f903775e0468d271ec62f5249.jpg
#   inflating: __MACOSX/screw_dataset/good/._056_png.rf.913e4a3f903775e0468d271ec62f5249.jpg
#   inflating: screw_dataset/good/217_png.rf.19e7c8d33d0572263e39e2b31e89430d.jpg
#   inflating: __MACOSX/screw_dataset/good/._217_png.rf.19e7c8d33d0572263e39e2b31e89430d.jpg

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc, precision_recall_curve, confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
import pathlib
import os
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# Configuration
DATA_DIR = "./screw_dataset"
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
SEED = 42
TEST_RATIO = 0.15
VAL_RATIO = 0.15
MODEL_SAVE_PATH = 'mon_cnn.h5'
INITIAL_LR = 0.002  # Learning rate augmenté (était 0.001 par défaut)

# --------------------------------------------------
# Les autres fonctions restent identiques...
# --------------------------------------------------

# --------------------------------------------------
# Étape 6: Création et entraînement du modèle (Learning rate augmenté)
# --------------------------------------------------
def create_and_train_model():
    """
    Crée et entraîne le modèle CNN basé sur MobileNetV2.

    Returns:
        tuple: (model, history, test_dataset)
    """
    # Obtenir les datasets et le nombre de steps
    (train_dataset, val_dataset, test_dataset, steps_per_epoch, validation_steps,
     X_train, X_val, X_test, y_train, y_val, y_test, classes) = data_pipeline()

    # Créer le modèle MobileNetV2
    base_model = MobileNetV2(
        input_shape=(224, 224, 3),
        include_top=False,
        weights='imagenet'
    )

    # Geler les couches de base_model
    base_model.trainable = False

    # Ajouter des couches personnalisées
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(1, activation='sigmoid')(x)

    # Créer le modèle final
    model = Model(inputs=base_model.input, outputs=predictions)

    # Utiliser un optimiseur Adam avec un learning rate plus élevé
    optimizer = Adam(learning_rate=INITIAL_LR)

    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy', tf.keras.metrics.Recall(name='recall')]
    )

    # Afficher le résumé du modèle
    model.summary()

    # Callbacks
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_lr=1e-6,
        verbose=1,
        mode='min'
    )

    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=5,
        mode='min',
        restore_best_weights=True
    )

    checkpoint = ModelCheckpoint(
        MODEL_SAVE_PATH,
        save_best_only=True,
        monitor='val_loss',
        mode='min'
    )

    # Entraînement du modèle
    print("\n" + "="*50)
    print("Démarrage de l'entraînement...")

    history = model.fit(
        train_dataset,
        epochs=50,
        steps_per_epoch=steps_per_epoch,
        validation_data=val_dataset,
        validation_steps=validation_steps,
        callbacks=[early_stopping, checkpoint, reduce_lr]
    )

    # Évaluation du modèle sur le dataset de test
    print("\n" + "="*50)
    print("Évaluation du modèle sur le test set...")
    test_results = model.evaluate(test_dataset)

    # Afficher les résultats
    metric_names = ['loss', 'accuracy', 'recall']
    for name, value in zip(metric_names, test_results):
        print(f"{name}: {value:.4f}")

    # Visualiser les courbes d'apprentissage
    plot_training_history(history)

    return model, history, test_dataset

# --------------------------------------------------
# Étape 8: Génération de la courbe ROC avec seuil personnalisé
# --------------------------------------------------
def generate_roc_curve_evaluation(min_recall=0.90):
    """
    Fonction pour évaluer le modèle et générer les courbes ROC.
    Permet de choisir un seuil qui garantit un rappel minimum (minimiser les faux négatifs).

    Args:
        min_recall: Rappel minimum souhaité (défaut=0.90)

    Returns:
        tuple: (roc_auc, pr_auc, optimal_threshold, optimal_custom_threshold)
    """
    print("="*50)
    print(f"Évaluation du modèle avec courbe ROC (rappel minimum: {min_recall:.2f})")
    print("="*50)

    # 1. Charger le modèle
    print("\nChargement du modèle...")
    model = load_model('mon_cnn.h5')

    # 2. Créer le dataset de test
    print("Création du dataset de test...")
    (_, _, test_dataset, _, _,
     _, _, X_test, _, _, y_test, classes) = data_pipeline()

    # Calculer le nombre d'exemples et d'étapes
    num_test_examples = len(X_test)
    test_steps = (num_test_examples + BATCH_SIZE - 1) // BATCH_SIZE  # Arrondi au supérieur

    # 3. Évaluer le modèle
    print("Évaluation du modèle...")
    test_loss, test_accuracy, test_recall = model.evaluate(
        test_dataset,
        steps=test_steps,
        verbose=1
    )

    print(f"\nPerformances avec le seuil par défaut (0.5):")
    print(f"Loss: {test_loss:.4f}")
    print(f"Accuracy: {test_accuracy:.4f}")
    print(f"Recall: {test_recall:.4f}")

    # 4. Générer les prédictions
    print("\nGénération des prédictions...")

    # Collecter toutes les prédictions
    y_true = []
    y_pred_proba = []

    for images, labels in test_dataset:
        batch_predictions = model.predict(images, verbose=0)
        y_true.extend(labels.numpy())
        y_pred_proba.extend(batch_predictions.flatten())

    # Assurer que nous avons le bon nombre d'exemples
    y_true = y_true[:num_test_examples]
    y_pred_proba = y_pred_proba[:num_test_examples]

    # 5. Tracer la courbe ROC
    print("Tracé de la courbe ROC...")
    fpr, tpr, thresholds = roc_curve(y_true, y_pred_proba)
    roc_auc = auc(fpr, tpr)

    # Trouver le seuil optimal standard (indice de Youden)
    optimal_idx = np.argmax(tpr - fpr)
    optimal_threshold = thresholds[optimal_idx]

    # Trouver le seuil qui garantit un rappel minimum (minimiser les faux négatifs)
    recall_idx = np.where(tpr >= min_recall)[0]
    if len(recall_idx) > 0:
        # Parmi les seuils avec un rappel suffisant, choisir celui avec la meilleure précision
        recall_thresholds = thresholds[recall_idx]
        recall_fprs = fpr[recall_idx]

        # Choisir le seuil avec le FPR minimal (meilleure précision) parmi ceux qui respectent le rappel minimum
        custom_optimal_idx = np.argmin(recall_fprs)
        custom_optimal_threshold = recall_thresholds[custom_optimal_idx]
        custom_optimal_recall = tpr[recall_idx[custom_optimal_idx]]
        custom_optimal_fpr = recall_fprs[custom_optimal_idx]
    else:
        # Si aucun seuil n'atteint le rappel minimum, prendre le seuil avec le meilleur rappel
        custom_optimal_idx = np.argmax(tpr)
        custom_optimal_threshold = thresholds[custom_optimal_idx]
        custom_optimal_recall = tpr[custom_optimal_idx]
        custom_optimal_fpr = fpr[custom_optimal_idx]

    # Créer une nouvelle figure
    plt.figure(figsize=(10, 8))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'Courbe ROC (AUC = {roc_auc:.3f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

    # Marquer les seuils optimaux
    plt.plot(fpr[optimal_idx], tpr[optimal_idx], 'ro', markersize=8,
             label=f'Seuil Youden = {optimal_threshold:.2f} (TPR={tpr[optimal_idx]:.2f}, FPR={fpr[optimal_idx]:.2f})')

    plt.plot(custom_optimal_fpr, custom_optimal_recall, 'go', markersize=8,
             label=f'Seuil Custom = {custom_optimal_threshold:.2f} (TPR={custom_optimal_recall:.2f}, FPR={custom_optimal_fpr:.2f})')

    # Ligne horizontale indiquant le rappel minimum
    plt.axhline(y=min_recall, color='r', linestyle='--', alpha=0.3, label=f'Rappel minimum = {min_recall}')

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Taux de faux positifs')
    plt.ylabel('Taux de vrais positifs')
    plt.title('Courbe ROC avec seuils optimaux')
    plt.legend(loc="lower right")
    plt.grid(alpha=0.3)

    plt.savefig('roc_curve_thresholds.png', dpi=300, bbox_inches='tight')
    plt.close()

    # 6. Tracer la courbe Précision-Rappel
    print("Tracé de la courbe Précision-Rappel...")
    precision, recall, pr_thresholds = precision_recall_curve(y_true, y_pred_proba)
    pr_auc = auc(recall, precision)

    plt.figure(figsize=(10, 8))
    plt.plot(recall, precision, color='darkgreen', lw=2, label=f'Courbe PR (AUC = {pr_auc:.3f})')

    # Trouver les indices correspondant aux seuils optimaux
    # Convertir les seuils ROC en indices de précision-rappel (approximativement)
    if len(pr_thresholds) > 0:
        # Trouver les indices de précision-rappel les plus proches des seuils optimaux
        optimal_pr_idx = np.abs(pr_thresholds - optimal_threshold).argmin() if len(pr_thresholds) > 0 else 0
        custom_optimal_pr_idx = np.abs(pr_thresholds - custom_optimal_threshold).argmin() if len(pr_thresholds) > 0 else 0

        # Marquer les points sur la courbe précision-rappel
        plt.plot(recall[optimal_pr_idx], precision[optimal_pr_idx], 'ro', markersize=8,
                label=f'Seuil Youden = {optimal_threshold:.2f} (P={precision[optimal_pr_idx]:.2f}, R={recall[optimal_pr_idx]:.2f})')

        plt.plot(recall[custom_optimal_pr_idx], precision[custom_optimal_pr_idx], 'go', markersize=8,
                label=f'Seuil Custom = {custom_optimal_threshold:.2f} (P={precision[custom_optimal_pr_idx]:.2f}, R={recall[custom_optimal_pr_idx]:.2f})')

    # Ligne verticale indiquant le rappel minimum
    plt.axvline(x=min_recall, color='r', linestyle='--', alpha=0.3, label=f'Rappel minimum = {min_recall}')

    plt.xlabel('Rappel')
    plt.ylabel('Précision')
    plt.title('Courbe Précision-Rappel avec seuils optimaux')
    plt.legend(loc="lower left")
    plt.grid(True, alpha=0.3)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])

    plt.savefig('precision_recall_curve_thresholds.png', dpi=300, bbox_inches='tight')
    plt.close()

    # 8. Tracer les matrices de confusion pour les différents seuils
    print("Tracé des matrices de confusion...")

    # Seuil par défaut (0.5)
    y_pred_default = (np.array(y_pred_proba) >= 0.5).astype(int)
    cm_default = confusion_matrix(y_true, y_pred_default)

    # Seuil optimal Youden
    y_pred_optimal = (np.array(y_pred_proba) >= optimal_threshold).astype(int)
    cm_optimal = confusion_matrix(y_true, y_pred_optimal)

    # Seuil optimal personnalisé
    y_pred_custom = (np.array(y_pred_proba) >= custom_optimal_threshold).astype(int)
    cm_custom = confusion_matrix(y_true, y_pred_custom)

    # Fonction pour afficher une matrice de confusion
    def plot_cm(cm, title, filename):
        plt.figure(figsize=(8, 6))
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title(title)
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)

        # Ajouter les valeurs dans les cellules
        thresh = cm.max() / 2
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                plt.text(j, i, format(cm[i, j], 'd'),
                        ha="center", va="center",
                        color="white" if cm[i, j] > thresh else "black")

        plt.tight_layout()
        plt.ylabel('Vraie classe')
        plt.xlabel('Classe prédite')
        plt.savefig(filename, dpi=300, bbox_inches='tight')
        plt.close()

    # Afficher les trois matrices de confusion
    plot_cm(cm_default, f'Matrice de confusion (seuil = 0.5)', 'confusion_matrix_default.png')
    plot_cm(cm_optimal, f'Matrice de confusion Youden (seuil = {optimal_threshold:.2f})', 'confusion_matrix_optimal.png')
    plot_cm(cm_custom, f'Matrice de confusion Custom (seuil = {custom_optimal_threshold:.2f})', 'confusion_matrix_custom.png')

    # Calculer et afficher les métriques pour chaque seuil
    metrics = []
    for threshold_name, threshold_value, y_pred in [
        ("Défaut (0.5)", 0.5, y_pred_default),
        (f"Youden ({optimal_threshold:.4f})", optimal_threshold, y_pred_optimal),
        (f"Custom ({custom_optimal_threshold:.4f})", custom_optimal_threshold, y_pred_custom)
    ]:
        acc = accuracy_score(y_true, y_pred)
        rec = recall_score(y_true, y_pred)
        prec = precision_score(y_true, y_pred)
        f1 = f1_score(y_true, y_pred)

        # Calculer les faux négatifs (FN) et faux positifs (FP)
        tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

        metrics.append({
            "Seuil": threshold_name,
            "Valeur": threshold_value,
            "Accuracy": acc,
            "Recall": rec,
            "Precision": prec,
            "F1 Score": f1,
            "VP": tp,
            "FP": fp,
            "FN": fn,
            "VN": tn
        })

    # Afficher le tableau comparatif des seuils
    print("\nComparaison des différents seuils:")
    print("="*100)
    print(f"{'Seuil':20} | {'Valeur':8} | {'Accuracy':8} | {'Recall':8} | {'Precision':8} | {'F1 Score':8} | {'VP':6} | {'FP':6} | {'FN':6} | {'VN':6}")
    print("-"*100)
    for m in metrics:
        print(f"{m['Seuil']:20} | {m['Valeur']:.4f} | {m['Accuracy']:.4f} | {m['Recall']:.4f} | {m['Precision']:.4f} | {m['F1 Score']:.4f} | {m['VP']:6d} | {m['FP']:6d} | {m['FN']:6d} | {m['VN']:6d}")

    # Recommandation de seuil
    print("\nRecommandation de seuil:")
    if custom_optimal_recall >= min_recall:
        print(f"Le seuil personnalisé ({custom_optimal_threshold:.4f}) atteint un rappel de {custom_optimal_recall:.4f} ≥ {min_recall:.2f} (minimum souhaité)")
        print(f"Ce seuil minimise les faux négatifs tout en préservant une précision de {precision[custom_optimal_pr_idx]:.4f}")
        recommended_threshold = custom_optimal_threshold
    else:
        print(f"Aucun seuil n'a pu atteindre le rappel minimum de {min_recall:.2f}. Le rappel maximum est de {custom_optimal_recall:.4f}")
        recommended_threshold = custom_optimal_threshold

    # Comparer avec le seuil de Youden
    print(f"\nLe seuil de Youden ({optimal_threshold:.4f}) offre un meilleur équilibre global entre vrais positifs et faux positifs")
    print(f"Mais il produit {metrics[1]['FN']} faux négatifs contre {metrics[2]['FN']} pour le seuil personnalisé.")

    print("\nRecommandation finale:")
    if metrics[2]['FN'] < metrics[1]['FN'] and metrics[2]['Accuracy'] > 0.75:  # Si le seuil personnalisé a moins de FN et une accuracy acceptable
        print(f"Utilisez le seuil personnalisé ({custom_optimal_threshold:.4f}) pour minimiser les faux négatifs tout en maintenant des performances acceptables.")
    else:
        print(f"Le seuil de Youden ({optimal_threshold:.4f}) offre un meilleur équilibre global. Utilisez-le si minimiser les faux positifs est aussi important.")

    return roc_auc, pr_auc, optimal_threshold, custom_optimal_threshold

# --------------------------------------------------
# Étape 9: Pipeline complet
# --------------------------------------------------
def run_complete_pipeline(retrain=True, min_recall=0.90):
    """
    Exécute le pipeline complet d'entraînement et d'évaluation.

    Args:
        retrain: Booléen pour déterminer si le modèle doit être réentraîné
        min_recall: Rappel minimum souhaité pour le seuil personnalisé

    Returns:
        tuple: (model, roc_auc, pr_auc, optimal_threshold, custom_threshold)
    """
    if retrain:
        # Entraîner le modèle
        model, _, _ = create_and_train_model()
    else:
        # Charger le modèle existant
        try:
            model = load_model(MODEL_SAVE_PATH)
            print(f"Modèle chargé depuis {MODEL_SAVE_PATH}")
        except:
            print(f"Impossible de charger le modèle depuis {MODEL_SAVE_PATH}. Entraînement d'un nouveau modèle.")
            model, _, _ = create_and_train_model()

    # Évaluer le modèle avec ROC
    roc_auc, pr_auc, optimal_threshold, custom_threshold = generate_roc_curve_evaluation(min_recall)

    print("\n" + "="*50)
    print("Pipeline complet exécuté avec succès!")
    print(f"Modèle enregistré sous: {MODEL_SAVE_PATH}")
    print(f"Performances: AUC-ROC = {roc_auc:.4f}, AUC-PR = {pr_auc:.4f}")
    print(f"Seuil Youden: {optimal_threshold:.4f}")
    print(f"Seuil personnalisé: {custom_threshold:.4f}")

    return model, roc_auc, pr_auc, optimal_threshold, custom_threshold

# --------------------------------------------------
# Exécution du code
# --------------------------------------------------
if __name__ == "__main__":
    # Pour exécuter le pipeline complet avec réentraînement
    # model, roc_auc, pr_auc, optimal_threshold, custom_threshold = run_complete_pipeline(retrain=True, min_recall=0.95)

    # Pour charger un modèle existant et l'évaluer sans réentraînement
    model, roc_auc, pr_auc, optimal_threshold, custom_threshold = run_complete_pipeline(retrain=False, min_recall=0.95)
# Out:
# Impossible de charger le modèle depuis mon_cnn.h5. Entraînement d'un nouveau modèle.
#
# ==================================================
# Chargement et division des données...
#
# Structure détectée:
# - bad: 285 images
# - good: 867 images
#
# Taille des datasets:
# - Entraînement: 806 images
# - Validation: 173 images
# - Test: 173 images
#
# === Avant augmentation ===
#
# Analyse de Train original:
# - Classe 0: 199 (24.7%)
# - Classe 1: 607 (75.3%)
#
# === Application de l'augmentation ===
#
# Configuration de l'entraînement:
# - Échantillons augmentés: 408
# - Nombre total d'échantillons: 1214
# - Steps per epoch: 37
# - Validation steps: 5
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 112, 112, 32)   │            864 │ input_layer_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 112, 112, 32)   │            128 │ Conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 112, 112, 32)   │              0 │ bn_Conv1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 112, 112, 32)   │            288 │ Conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 112, 112, 16)   │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 112, 112, 16)   │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 112, 112, 96)   │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 112, 112, 96)   │            384 │ block_1_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 112, 112, 96)   │              0 │ block_1_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 113, 113, 96)   │              0 │ block_1_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 56, 56, 96)     │            864 │ block_1_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 56, 56, 96)     │            384 │ block_1_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 56, 56, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 56, 56, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 56, 56, 24)     │             96 │ block_1_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_1_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_2_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_2_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 56, 56, 144)    │          1,296 │ block_2_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 56, 56, 144)    │            576 │ block_2_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 56, 56, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 56, 56, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 56, 56, 24)     │             96 │ block_2_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 56, 56, 24)     │              0 │ block_1_project_BN[0]… │
# │                           │                        │                │ block_2_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_2_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_3_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_3_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 57, 57, 144)    │              0 │ block_3_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 28, 28, 144)    │          1,296 │ block_3_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 28, 28, 144)    │            576 │ block_3_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 28, 28, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 28, 28, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 28, 28, 32)     │            128 │ block_3_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_3_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_4_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_4_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_4_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_4_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 28, 28, 32)     │            128 │ block_4_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_3_project_BN[0]… │
# │                           │                        │                │ block_4_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_4_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_5_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_5_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_5_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_5_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 28, 28, 32)     │            128 │ block_5_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_4_add[0][0],     │
# │                           │                        │                │ block_5_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_5_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_6_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_6_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 29, 29, 192)    │              0 │ block_6_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 14, 14, 192)    │          1,728 │ block_6_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 14, 14, 192)    │            768 │ block_6_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 14, 14, 192)    │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 14, 14, 64)     │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 14, 14, 64)     │            256 │ block_6_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_6_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_7_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_7_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_7_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_7_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 14, 14, 64)     │            256 │ block_7_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_6_project_BN[0]… │
# │                           │                        │                │ block_7_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_7_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_8_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_8_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_8_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_8_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 14, 14, 64)     │            256 │ block_8_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_7_add[0][0],     │
# │                           │                        │                │ block_8_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_8_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_9_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_9_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_9_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_9_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 14, 14, 64)     │            256 │ block_9_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_8_add[0][0],     │
# │                           │                        │                │ block_9_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 14, 14, 384)    │         24,576 │ block_9_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 14, 14, 384)    │          1,536 │ block_10_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 14, 14, 384)    │              0 │ block_10_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 14, 14, 384)    │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 14, 14, 384)    │          1,536 │ block_10_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 14, 14, 384)    │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 14, 14, 96)     │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 14, 14, 96)     │            384 │ block_10_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_10_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_11_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_11_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_11_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 14, 14, 96)     │            384 │ block_11_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_10_project_BN[0… │
# │                           │                        │                │ block_11_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_11_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_12_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_12_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_12_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 14, 14, 96)     │            384 │ block_12_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_11_add[0][0],    │
# │                           │                        │                │ block_12_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_12_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_13_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_13_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 15, 15, 576)    │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 7, 7, 576)      │          5,184 │ block_13_pad[0][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 7, 7, 576)      │          2,304 │ block_13_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 7, 7, 576)      │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 7, 7, 160)      │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 7, 7, 160)      │            640 │ block_13_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_13_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_14_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_14_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_14_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 7, 7, 160)      │            640 │ block_14_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_13_project_BN[0… │
# │                           │                        │                │ block_14_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_14_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_15_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_15_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_15_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 7, 7, 160)      │            640 │ block_15_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_14_add[0][0],    │
# │                           │                        │                │ block_15_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_15_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_16_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_16_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_16_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 7, 7, 320)      │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 7, 7, 320)      │          1,280 │ block_16_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 7, 7, 1280)     │        409,600 │ block_16_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 7, 7, 1280)     │          5,120 │ Conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 7, 7, 1280)     │              0 │ Conv_1_bn[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1280)           │              0 │ out_relu[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 128)            │        163,968 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 128)            │              0 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 1)              │            129 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,422,081 (9.24 MB)
#  Trainable params: 164,097 (641.00 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# ==================================================
# Démarrage de l'entraînement...
# Epoch 1/50
# 32/37 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6273 - loss: 0.7027 - recall: 0.7466
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 23s 196ms/step - accuracy: 0.6320 - loss: 0.6969 - recall: 0.7503 - val_accuracy: 0.7563 - val_loss: 0.5872 - val_recall: 0.9667 - learning_rate: 0.0020
# Epoch 2/50
# 31/37 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7847 - loss: 0.4867 - recall: 0.9271
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - accuracy: 0.7836 - loss: 0.4885 - recall: 0.9234 - val_accuracy: 0.7625 - val_loss: 0.5539 - val_recall: 0.9750 - learning_rate: 0.0020
# Epoch 3/50
# 31/37 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7798 - loss: 0.4854 - recall: 0.8892
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 113ms/step - accuracy: 0.7824 - loss: 0.4821 - recall: 0.8919 - val_accuracy: 0.7625 - val_loss: 0.5510 - val_recall: 0.9417 - learning_rate: 0.0020
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - accuracy: 0.7757 - loss: 0.4374 - recall: 0.8549 - val_accuracy: 0.7375 - val_loss: 0.5733 - val_recall: 0.8667 - learning_rate: 0.0020
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.7999 - loss: 0.4558 - recall: 0.9192 - val_accuracy: 0.7063 - val_loss: 0.6006 - val_recall: 0.7500 - learning_rate: 0.0020
# Epoch 6/50
# 31/37 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8201 - loss: 0.3901 - recall: 0.8961
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.8215 - loss: 0.3896 - recall: 0.9015 - val_accuracy: 0.7375 - val_loss: 0.5446 - val_recall: 0.8833 - learning_rate: 0.0020
# Epoch 7/50
# 30/37 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8306 - loss: 0.3911 - recall: 0.8910
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.8310 - loss: 0.3903 - recall: 0.8954 - val_accuracy: 0.7750 - val_loss: 0.5090 - val_recall: 0.9083 - learning_rate: 0.0020
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - accuracy: 0.8475 - loss: 0.3563 - recall: 0.9013 - val_accuracy: 0.7688 - val_loss: 0.5109 - val_recall: 0.9417 - learning_rate: 0.0020
# Epoch 9/50
# 31/37 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8517 - loss: 0.3231 - recall: 0.9194
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - accuracy: 0.8514 - loss: 0.3253 - recall: 0.9204 - val_accuracy: 0.7937 - val_loss: 0.5004 - val_recall: 0.9333 - learning_rate: 0.0020
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.8600 - loss: 0.3355 - recall: 0.9310 - val_accuracy: 0.7750 - val_loss: 0.5108 - val_recall: 0.9417 - learning_rate: 0.0020
# Epoch 11/50
# 31/37 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8530 - loss: 0.3307 - recall: 0.9121
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 21s 315ms/step - accuracy: 0.8544 - loss: 0.3303 - recall: 0.9149 - val_accuracy: 0.7937 - val_loss: 0.4951 - val_recall: 0.9333 - learning_rate: 0.0020
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 20s 306ms/step - accuracy: 0.8924 - loss: 0.2974 - recall: 0.9440 - val_accuracy: 0.7937 - val_loss: 0.5230 - val_recall: 0.9000 - learning_rate: 0.0020
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.8748 - loss: 0.2819 - recall: 0.9452 - val_accuracy: 0.7437 - val_loss: 0.5401 - val_recall: 0.8000 - learning_rate: 0.0020
# Epoch 14/50
# 31/37 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8863 - loss: 0.2718 - recall: 0.9190
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0010000000474974513.
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.8864 - loss: 0.2727 - recall: 0.9220 - val_accuracy: 0.7937 - val_loss: 0.5113 - val_recall: 0.9167 - learning_rate: 0.0020
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.8805 - loss: 0.2669 - recall: 0.9311 - val_accuracy: 0.7750 - val_loss: 0.5109 - val_recall: 0.8583 - learning_rate: 0.0010
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - accuracy: 0.9112 - loss: 0.2242 - recall: 0.9492 - val_accuracy: 0.7875 - val_loss: 0.5091 - val_recall: 0.9333 - learning_rate: 0.0010
#
# ==================================================
# Évaluation du modèle sur le test set...
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 341ms/step - accuracy: 0.8387 - loss: 0.4069 - recall: 0.9770
# loss: 0.4419
# accuracy: 0.8150
# recall: 0.9692
# ==================================================
# Évaluation du modèle avec courbe ROC (rappel minimum: 0.95)
# ==================================================
#
# Chargement du modèle...
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Création du dataset de test...
#
# ==================================================
# Chargement et division des données...
#
# Structure détectée:
# - bad: 285 images
# - good: 867 images
#
# Taille des datasets:
# - Entraînement: 806 images
# - Validation: 173 images
# - Test: 173 images
#
# === Avant augmentation ===
#
# Analyse de Train original:
# - Classe 0: 199 (24.7%)
# - Classe 1: 607 (75.3%)
#
# === Application de l'augmentation ===
#
# Configuration de l'entraînement:
# - Échantillons augmentés: 408
# - Nombre total d'échantillons: 1214
# - Steps per epoch: 37
# - Validation steps: 5
# Évaluation du modèle...
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.8387 - loss: 0.4069 - recall: 0.9770
#
# Performances avec le seuil par défaut (0.5):
# Loss: 0.4419
# Accuracy: 0.8150
# Recall: 0.9692
#
# Génération des prédictions...
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d88806b62a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Tracé de la courbe ROC...
# Tracé de la courbe Précision-Rappel...
# Tracé des matrices de confusion...
#
# Comparaison des différents seuils:
# ====================================================================================================
# Seuil                | Valeur   | Accuracy | Recall   | Precision | F1 Score | VP     | FP     | FN     | VN
# ----------------------------------------------------------------------------------------------------
# Défaut (0.5)         | 0.5000 | 0.8150 | 0.9692 | 0.8182 | 0.8873 |    126 |     28 |      4 |     15
# Youden (0.7574)      | 0.7574 | 0.7919 | 0.8231 | 0.8917 | 0.8560 |    107 |     13 |     23 |     30
# Custom (0.6463)      | 0.6463 | 0.8555 | 0.9538 | 0.8671 | 0.9084 |    124 |     19 |      6 |     24
#
# Recommandation de seuil:
# Le seuil personnalisé (0.6463) atteint un rappel de 0.9538 ≥ 0.95 (minimum souhaité)
# Ce seuil minimise les faux négatifs tout en préservant une précision de 0.8671
#
# Le seuil de Youden (0.7574) offre un meilleur équilibre global entre vrais positifs et faux positifs
# Mais il produit 23 faux négatifs contre 6 pour le seuil personnalisé.
#
# Recommandation finale:
# Utilisez le seuil personnalisé (0.6463) pour minimiser les faux négatifs tout en maintenant des performances acceptables.
#
# ==================================================
# Pipeline complet exécuté avec succès!
# Modèle enregistré sous: mon_cnn.h5
# Performances: AUC-ROC = 0.8123, AUC-PR = 0.9154
# Seuil Youden: 0.7574
# Seuil personnalisé: 0.6463
